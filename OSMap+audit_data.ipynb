# %% [markdown]
# # Data Wrangle  - Data Audit and Clean
#
# ### Downloaded the file from https://www.openstreetmap.org/relation/324211
#
# ### 1. Creating the Sample Toronto OSM file.

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

import xml.etree.ElementTree as ET  # Use cElementTree or lxml if too slow

OSM_FILE = "toronto_canada.osm"  # Replace this with your osm file
SAMPLE_FILE = "torontosample.osm"

k = 15 # Parameter: take every k-th top level element

def get_element(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag

    Reference:
    http://stackoverflow.com/questions/3095434/inserting-newlines-in-xml-file-generated-via-xml-etree-elementtree-in-python
    """
    context = iter(ET.iterparse(osm_file, events=('start', 'end')))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()


with open(SAMPLE_FILE, 'wb') as output:
    output.write('<?xml version="1.0" encoding="UTF-8"?>\n')
    output.write('<osm>\n  ')

    # Write every kth top level element
    for i, element in enumerate(get_element(OSM_FILE)):
        if i % k == 0:
            output.write(ET.tostring(element, encoding='utf-8'))

    output.write('</osm>')

# %% [markdown]
# ### 2. Audit the Data

# %% [raw]
# 1. My task is to use the iterative parsing to process the map file and find out not only what tags are there, but also how many, to get the feeling on how much of which data I can expect to have in the map.

# %%
"""
It should return a dictionary with the tag name as the key and number of times this tag can be encountered in 
the map as value.

"""
import xml.etree.cElementTree as ET
import pprint

def count_tags(filename):
    dict_ = {}
    for event,elem in ET.iterparse(filename):
        if elem.tag not in dict_:
            dict_[elem.tag] = 1
        else:
            dict_[elem.tag] += 1
    return dict_

def test():
    tags = count_tags('toronto_canada.osm')
    #tags = count_tags('torontosample.osm')
    pprint.pprint(tags) 

if __name__ == "__main__":
    test()
# Out:
# {'bounds': 1,
#  'member': 151372,
#  'nd': 5875055,
#  'node': 5127518,
#  'osm': 1,
#  'relation': 9677,
#  'tag': 5030403,
#  'way': 761285}

# %% [raw]
# 2. Here my task is to explore the data more. Before I process the data and add it into your database, I am checking the
# "k" value for each "<tag>" and see if there are any potential problems.

# %%
"""
From lecture I have 3 regular expressions to check for certain patterns in the tags.
I would like to change the data model and expand the "addr:street" type of keys to a dictionary like this:
{"address": {"street": "Some value"}}

So, I want to see. I have such tags, and if I have any tags with problematic characters.

I have a count of each of four tag categories in a dictionary:
1.  "lower"        - for tags that contain only lowercase letters and are valid
2.  "lower_colon"  - for otherwise valid tags with a colon in their names
3.  "problemchars" - for tags with problematic characters 
4.  "other"        - for other tags that do not fall into the other three categories.

"""
import xml.etree.cElementTree as ET
import pprint
import re

lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

osm_file = "toronto_canada.osm"
#osm_file = "torontosample.osm"

def key_type(element, keys):
    if element.tag == "tag":
        att = element.attrib['k'] 
        m = lower.search(att)
        p = problemchars.search(att)
        n = lower_colon.search(att)
        if m:
            keys["lower"] += 1
        elif n:
            keys["lower_colon"] += 1
        elif p:
            keys["problemchars"] += 1
        else:
            keys["other"] += 1
#pass    
    return keys

def process_map(filename):
    keys = {"lower": 0, "lower_colon": 0, "problemchars": 0, "other": 0}
    for _, element in ET.iterparse(filename):
        keys = key_type(element, keys)

    return keys

def test():
    #keys = process_map('torontosample.osm')
    keys = process_map(osm_file)
    pprint.pprint(keys)

if __name__ == "__main__":
    test()
# Out:
# {'lower': 2970797,
#  'lower_colon': 1939747,
#  'other': 119222,
#  'problemchars': 637}

# %%
3. I am auditing and finding the abbreviated street name.

# %%
"""
The OSM file used is an abbreviated version of the Toronto Mapzen file  
"""

import xml.etree.cElementTree as ET
from collections import defaultdict
import re

#osm_file = open("torontosample.osm", "r")
osm_file = open("toronto_canada.osm", "r")
street_type_re = re.compile(r'\S+\.?$', re.IGNORECASE)
street_types = defaultdict(int)

def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()

        street_types[street_type] += 1

def print_sorted_dict(d):
    keys = d.keys()
    keys = sorted(keys, key=lambda s: s.lower())  # Python 2.7 ver
    for k in keys:
        v = d[k]
        print "%s: %d" % (k, v) 

def is_street_name(elem):
    return (elem.tag == "tag") and (elem.attrib['k'] == "addr:street")

def audit():
    for event, elem in ET.iterparse(osm_file):
        if is_street_name(elem):
            audit_street_type(street_types, elem.attrib['v'
# Quay: 8
# Queensville: 33
# Queensway: 409
# R: 1
# Rd: 51
# rd: 1
# Reign: 8
# Ridge: 314
# Rise: 44
# Road: 76920
# Roadway: 5
# Robertoway: 4
# Robinway: 22
# Romanoway: 9
# Rosedale: 2
# Roseway: 49
# Round: 12
# Row: 89
# Royalway: 18
# Run: 174
# S: 3
# S.: 1
# Sageway: 10
# School: 1
# Serences: 4
# Shepway: 34
# Sherbourne: 6
# Shores: 4
# Sideline: 36
# Sideroad: 1415
# Sound: 17
# South: 6517
# Sparroway: 8
# Square: 1404
# St: 98
# St.: 4
# Stables: 6
# Stan: 10
# Starway: 40
# STREET: 1
# street: 2
# Street: 61415
# Sunset: 2
# Taylor: 8
# Tecumseth: 4
# Teodoro: 18
# Terace: 1
# Terrace: 1803
# Terraces: 4
# Terrance: 6
# Thicket: 4
# Toronto: 4
# Toscana: 24
# Tosorontio: 67
# Tottenham: 8
# Townline: 349
# Trail: 5969
# Trailway: 6
# Treeway: 78
# Trl: 1
# Unionville: 37
# Vale: 8
# Valecrest: 20
# Valley: 10
# Valleybrae: 20
# Valleyscape: 36
# Valleyway: 43
# Varoway: 2
# Verde: 4
# View: 10
# Villaway: 37
# Vineway: 62
# Vista: 17
# Vitoway: 4
# W: 37
# w: 1
# W.: 2
# Walk: 197
# Walkway: 16
# Way: 5923
# west: 2
# West: 15295
# Westway: 113
# Wheelway: 18
# Willoway: 20
# Winegarden: 4
# Wishbone: 8
# Wold: 16
# Wood: 117
# Woodlands: 83
# Woodmount: 8
# Woods: 59
# Woodway: 4
# Wrenway: 26
# Wynd: 4
# Yonge: 1

# %% [markdown]
# ## 3. Imporving Stree Names, Postal Codes and Phone Numbers

# %%
4. Mapping the Street name to the expected name.
   After mapped to the expected names write the data to "toronto_canada1.osm" file

# %%
import xml.etree.cElementTree as ET
from collections import defaultdict
import re
import pprint
 
OSM_FILE = "toronto_canada.osm"
#OSM_FILE = "torontosample.osm"
street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)


expected = ["Street", "Avenue", "Boulevard", "Drive", "Court", "Place", "Square", "Lane", "Road", 
            "Trail", "Parkway", "Commons", "Terrace" ,"Expressway", "Crescent", "Close", "Common", "Heights", "Way"]

mapping = { "St": "Street",
            "St.": "Street",
            "ST": "Street",
            "Ben":"Bend",
            "Glenn":"Glen",
            "Hrbr":"Harbour",
            "Ho":"Hollow",
            "Mews":"Medows",
            "Pkwy":"Parkway",
            "Wood":"Woods",
            "Ave": "Avenue",
            "ave": "Avenue",
            "Rd.": "Road",
            "Blvd":"Boulevard",
            "Dr.":"Drive",
            "Ct":"Court",
            "Pl":"Place",
            "Sq":"Square",
            "ln":"Lane",
            "SW": "Southwest ",
            "SE": "Southeast ",
            "NW": "Northwest ",
            "NE": "Northeast ",
            'CT': 'Court',
            'Ct': 'Court',
            'Dr': 'Drive',
            'Dr.': 'Drive',
            'E': 'East',
            'Main St': 'Main Street',
            'N': 'North',
            'NE': 'Northeast',
            'NW': 'Northwest',
            'nw': 'Northwest',
            'PL': 'Place',
            'Pl': 'Place',
            'Rd': 'Road',
            'RD': 'Road',
            'Rd.': 'Road',
            'S': 'South',
            'S.': 'South',
            'SE': 'Southeast',
            'ST': 'Street',
            'SW': 'Southwest',
            'SW,': 'Southwest',
            'Se': 'Southeast',
            'southeast': 'Southeast',
            'St': 'Street',
            'st': 'Street',
            'Ter': 'Terrace',
            'W': 'West',
            'west': 'West',
            'HYW': 'Highway',
            'WY': 'Way',
            "Avebue":"Avenue",
            "Avenu":"Avenue"
            }


def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)

def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")

def audit(osmfile):
    osm_file = open(osmfile, "r")
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])
    osm_file.close()
    return street_types

def update_name(name, mapping):
    m = street_type_re.search(name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            if street_type in mapping.keys():
                name = re.sub(street_type_re, mapping[street_type], name)
                               
    return name

#OSM_FILE_UPDATED = "toronto_canada1.osm"

"""
def test():
    st_types = audit(OSM_FILE)
    pprint.pprint(dict(st_types))

    for st_type, ways in st_types.iteritems():
        for name in ways:
            better_name = update_name(name, mapping)
            print name, "=>", better_name

if __name__ == '__main__':
    test()
    
"""
# Mapped to the expected names, save/write the data to "toronto_canada1.osm" file 

OSM_FILE_UPDATED = "toronto_canada1.osm"
# Takes as input osm file and tuple of nodes and yield nodes of types from tuple. 

def get_element(osm_file, tags=('node', 'way', 'relation')):
    context = iter(ET.iterparse(osm_file, events=('start', 'end')))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()
            
# Following function will update the abbreviations in osm file

def update_street(original_file, update_file):
    with open(update_file, 'wb') as output:
        output.write('<?xml version="1.0" encoding="UTF-8"?>\n')
        output.write('<osm>\n  ') 
        for i, element in enumerate(get_element(original_file)):
            for tag in element.iter("tag"):
                if is_street_name(tag):
                    tag.set('v',update_name(tag.attrib['v'], mapping))
            output.write(ET.tostring(element, encoding='utf-8'))
        output.write('</osm>')

update_street(OSM_FILE, OSM_FILE_UPDATED)

# %%
5. Auditing the for postcode inconsistent

# %%
import xml.etree.cElementTree as ET
from collections import defaultdict
import re

postcode_type_re = re.compile(r'\d{5}-??')

def audit_post_type(post_types, zip):
    m = postcode_type_re.search(zip)
    if m:
        post_type = m.group()
        if post_type not in post_types:
            post_types[post_type].add(zip)
    else:
        post_types['unknown'].add(zip)

def is_pcode(elem):
    return (elem.attrib['k'] == "addr:postcode")

def postcode_audit(osmfile):
    osm_file = open(osmfile, "r")    
    post_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):
        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_pcode(tag):
                    audit_post_type(post_types, tag.attrib['v'])                
    osm_file.close()
    return post_types

postcode_types = postcode_audit(OSM_FILE_UPDATED)

pprint.pprint(dict(postcode_types))

OSM_FILE_UPDATED_PC = "toronto_canada2.osm"
# This function replace abbrevition by right zip
def u_postcode(zip):
    m = postcode_type_re.search(zip)
    if m:
        return m.group()
    else:
        return 'unknown'

# This function replace wrong zip in osm file
def update_postcode(original_file, update_file):
    with open(update_file, 'wb') as output:
        output.write('<?xml version="1.0" encoding="UTF-8"?>\n')
        output.write('<osm>\n  ') 
        for i, element in enumerate(get_element(original_file)):
            for tag in element.iter("tag"):
                if is_pcode(tag):
                    tag.set('v',u_postcode(tag.attrib['v']))
            output.write(ET.tostring(element, encoding='utf-8'))
        output.write('</osm>')

update_postcode(OSM_FILE_UPDATED, OSM_FILE_UPDATED_PC)
# Out:
# {'14174': set(['14174']),
#  '33913': set(['33913']),
#  '96734': set(['96734']),
#  'unknown': set(['B2W 5M5',
#                  'B2Y4N4',
#                  'K4A 1W9',
#                  'L0B 1A0',
#                  'L0B 1J0',
#                  'L0B 1L0',
#                  'L0C 1A0',
#                  'L0C 1B0',
#                  'L0C 1K0',
#                  'L0E 1T0',
#                  'L0G 1A0',
#                  'L0G 1B0',
#                  'L0G 1J0',
#                  'L0G 1L0',
#                  'L0G 1M0',
#                  'L0G 1N0',
#                  'L0G 1R0',
#                  'L0G 1T0',
#                  'L0G 1V0',
#                  'L0G 1W0',
#                  'L0G1A0',
#                  'L0G1M0',
#                  'L0G1T0',
#                  'L0G1W0',
#                  'L0H 1G0',
#                  'L0J 1C0',
#                  'L0L 1L0',
#                  'L0M 1A0',
#                  'L0N 1A0',
#                  'L0N 1B0',
#                  'L0N 1C0',
#                  'L0N 1E0',
#                  'L0N 1M0',
#                  'L0N 1N0',
#                  'L0N 1P0',
#                  'L0N 1R0',
#                  'L0N 1S8',
#                  'L0N1M0',
#                  'L0P 1B0',
#                  'L0P 1C0',
#                  'L0P1B0',
#                  'L0R',
#                  'L0R 1T0',
#                  'L0R 1X0',
#                  'L0R 2H0',
#                  'L0R 2H7',
#                  'L0R2H5',
#                  'L0S 1J0',
#                  'L0S 1T0',
#                  'L0S1J0',
#                  'L1C 4J1',
#                  'L1E 0E2',
#                  'L1E 2K8',
#                  'L1E 2M8',
#                  'L1E 2S7',
#                  'L1E 3B4',
#                  'L1E 3C8',
#                  'L1E 3J2',
#                  'L1G 0A5',
#                  'L1G 1A1',
#                  'L1G 1A2',
#                  'L1G 1A8',
#                  'L1G 1B2',
#                  'L1G 1B5',
#                  'L1G 1C7',
#                  'L1G 1J8',
#                  'L1G 1J9',
#                  'L1G 1L6',
#                  'L1G 2B9',
#                  'L1G 2C4',
#                  'L1G 3T4',
#                  'L1G 4B7',
#                  'L1G 4R7',
#                  'L1G 4S2',
#                  'L1G 4T5',
#                  'L1G 4W1',
#                  'L1G 4X8',
#                  'L1G 6L4',
#                  'L1G 7C7',
#                  'L1H',
#                  'L1H 1A9',
#                  'L1H 1B2',
#                  'L1H 1H8',
#                  'L1H 1H9',
#                  'L1H 1J5',
#                  'L1H 1J7',
#                  'L1H 1N2',
#                  'L1H 2C6',
#                  'L1H 2E7',
#                  'L1H 2R2',
#                  'L1H 3X1',
#                  'L1H 3Z4',
#                  'L1H 3Z5',
#                  'L1H 3Z6',
#                  'L1H 3Z7',
#                  'L1H 4G1',
#                  'L1H 4G3',
#                  'L1H 4M9',
#                  'L1H 6C9',
#                  'L1H 7G9',
#                  'L1H 7J2',
#                  'L1H 7K4',
#                  'L1H 7K5',
#                  'L1H 7L7',
#                  'L1H 8B7',
#                  'L1H 8C1',
#                  'L1H 8S1',
#                  'L1H7K5',
#                  'L1J 0A1',
#                  'L1J 0A8',
#                  'L1J 1G5',
#                  'L1J 1P5',
#                  'L1J 2L3',
#                  'L1J 2L4',
#                  'L1J 4E9',
#                  'L1J 5Y2',
#                  'L1J 5Y6',
#                  'L1J 6T8',
#                  'L1J 6W7',
#                  'L1J 7J1',
#                  'L1K 0G1',
#                  'L1K 0J6',
#                  'L1K 0S8',
#                  'L1K 2H4',
#                  'L1K 2H5',
#                  'L1K 2H6',
#                  'L1K 2J6',
#                  'L1K 3B5',
#                  'L1K0S1',
#                  'L1M 1A2',
#                  'L1M 1K5',
#                  'L1M 1Y1',
#                  'L1N 0H1',
#                  'L1N 0J2',
#                  'L1N 1H8',
#                  'L1N 2J2',
#                  'L1N 3K4',
#                  'L1N 4K7',
#                  'L1N 6J3',
#                  'L1N 8M3',
#                  'L1N 8W9',
#                  'L1N 8Y8',
#                  'L1N6A3',
#                  'L1N8Y9',
#                  'L1P 1V3',
#                  'L1R 1H2',
#                  'L1R 2P2',
#                  'L1R 3A5',
#                  'L1R 3E8',
#                  'L1R0H5',
#                  'L1R3L7',
#                  'L1S 0A1',
#                  'L1S 1G1',
#                  'L1S 1P2',
#                  'L1S 1P5',
#                  'L1S 2G6',
#                  'L1S 3Z2',
#                  'L1S 7G9',
#                  'L1T 0H4',
#                  'L1T 1X5',
#                  'L1T 3A3',
#                  'L1V 1B8',
#                  'L1V 1W2',
#                  'L1V 3B4',
#                  'L1V 3M9',
#                  'L1V 3V8',
#                  'L1V 3Y9',
#                  'L1V 6L2',
#                  'L1V2W8',
#                  'L1W 1W7',
#                  'L1W 1Z6',
#                  'L1W 2G9',
#                  'L1W 3S3',
#                  'L1W3R2',
#                  'L1W3Z6',
#                  'L1W3Z7',
#                  'L1X 1V4',
#                  'L1X 2N1',
#                  'L1Y 1A4',
#                  'L1Z 0C7',
#                  'L1Z 0E7',
#                  'L1Z 1L4',
#                  'L2M 7C4',
#                  'L2N 2T5',
#                  'L3B 5Y2',
#                  'L3M 4E8',
#                  'L3P 1K7',
#                  'L3P 1Y6',
#                  'L3P 2E7',
#                  'L3P 2S7',
#                  'L3P 2Y2',
#                  'L3P 3B4',
#                  'L3P 3G6',
#                  'L3P 3J3',
#                  'L3P 3X4',
#                  'L3P 4B5',
#                  'L3P 4P8',
#                  'L3P 6C6',
#                  'L3P 8M1',
#                  'L3R 0B5',
#                  'L3R 0B8',
#                  'L3R 0E7',
#                  'L3R 0G6',
#                  'L3R 0J3',
#                  'L3R 0J5',
#                  'L3R 0N2',
#                  'L3R 0T4',
#                  'L3R 0T9',
#                  'L3R 0W7',
#                  'L3R 0Y5',
#                  'L3R 1A3',
#                  'L3R 1A5',
#                  'L3R 1A7',
#                  'L3R 1B1',
#                  'L3R 1G9',
#                  'L3R 1K9',
#                  'L3R 1L5',
#                  'L3R 1L7',
#                  'L3R 1M5',
#                  'L3R 1N1',
#                  'L3R 1V6',
#                  'L3R 1Z9',
#                  'L3R 2A2',
#                  'L3R 2B3',
#                  'L3R 2E4',
#                  'L3R 2G5',
#                  'L3R 2G6',
#                  'L3R 2G8',
#                  'L3R 2G9',
#                  'L3R 2H2',
#                  'L3R 2M4',
#                  'L3R 2R4',
#                  'L3R 3P3',
#                  'L3R 3V7',
#                  'L3R 4G8',
#                  'L3R 4G9',
#                  'L3R 4M9',
#                  'L3R 4Z6',
#                  'L3R 5A2',
#                  'L3R 5B4',
#                  'L3R 5B5',
#                  'L3R 5E4',
#                  'L3R 5J2',
#                  'L3R 5M6',
#                  'L3R 5X5',
#                  'L3R 5Y2',
#                  'L3R 5Y8',
#                  'L3R 6C9',
#                  'L3R 6E4',
#                  'L3R 6Z8',
#                  'L3R 7W8',
#                  'L3R 8B8',
#                  'L3R 8E3',
#                  'L3R 8R9',
#                  'L3R 8X6',
#                  'L3R 9C2',
#                  'L3R 9N6',
#                  'L3R 9P6',
#                  'L3R 9S5',
#                  'L3R 9S9',
#                  'L3R 9T1',
#                  'L3R 9V8',
#                  'L3R0L2',
#                  'L3R2A2',
#                  'L3R2G9',
#                  'L3R5B4',
#                  'L3S 1E9',
#                  'L3S 1Y4',
#                  'L3S 2H4',
#                  'L3S 2J3',
#                  'L3S 2J4',
#                  'L3S 3L5',
#                  'L3S 3P7',
#                  'L3T 0A5',
#                  'L3T 1A8',
#                  'L3T 1C6',
#                  'L3T 1J3',
#                  'L3T 1N2',
#                  'L3T 1N3',
#                  'L3T 1N4',
#                  'L3T 2A8',
#                  'L3T 2S4',
#                  'L3T 2S5',
#                  'L3T 2S6',
#                  'L3T 2T4',
#                  'L3T 2T5',
#                  'L3T 2T6',
#                  'L3T 2T7',
#                  'L3T 2T8',
#                  'L3T 2T9',
#                  'L3T 2V3',
#                  'L3T 2V4',
#                  'L3T 2V5',
#                  'L3T 2V9',
#                  'L3T 2W1',
#                  'L3T 2W2',
#                  'L3T 2W3',
#                  'L3T 2W5',
#                  'L3T 2X7',
#                  'L3T 2Y1',
#                  'L3T 2Y3',
#                  'L3T 2Y4',
#                  'L3T 2Y5',
#                  'L3T 3V2',
#                  'L3T 4P6',
#                  'L3T 4R5',
#                  'L3T 5V4',
#                  'L3T 5W7',
#                  'L3T 6L2',
#                  'L3T 6T5',
#                  'L3T 7E1',
#                  'L3T 7S5',
#                  'L3T 7Y3',
#                  'L3T2A5',
#                  'L3T6L2',
#                  'L3X 1L9',
#                  'L3X 1S3',
#                  'L3X 1V6',
#                  'L3X 2V3',
#                  'L3Y',
#                  'L3Y 0C1',
#                  'L3Y 1L8',
#                  'L3Y 1M5',
#                  'L3Y 1W1',
#                  'L3Y 1X4',
#                  'L3Y 1Z9',
#                  'L3Y 2K4',
#                  'L3Y 2N1',
#                  'L3Y 2N7',
#                  'L3Y 2P8',
#                  'L3Y 2R4',
#                  'L3Y 2R5',
#                  'L3Y 2Y7',
#                  'L3Y 3E4',
#                  'L3Y 3H4',
#                  'L3Y 3J9',
#                  'L3Y 3L1',
#                  'L3Y 3N3',
#                  'L3Y 3T7',
#                  'L3Y 3Y1',
#                  'L3Y 3Y3',
#                  'L3Y 3Y8',
#                  'L3Y 3Y9',
#                  'L3Y 3Z4',
#                  'L3Y 4V8',
#                  'L3Y 4V9',
#                  'L3Y 4W1',
#                  'L3Y 4W5',
#                  'L3Y 4Z1',
#                  'L3Y 5L8',
#                  'L3Y 7P6',
#                  'L3Y 7R5',
#                  'L3Y 7R6',
#                  'L3Y 7R8',
#                  'L3Y 7R9',
#                  'L3Y 7T8',
#                  'L3Y 8B3',
#                  'L3Y 8G7',
#                  'L3Y 8H1',
#                  'L3Y 8J7',
#                  'L3Y 8S3',
#                  'L3Y 8S4',
#                  'L3Y 8W8',
#                  'L3Y 8Z2',
#                  'L3Y 9A4',
#                  'L3Y3T3',
#                  'L3Y3Z3',
#                  'L3Y4X2',
#                  'L3Z 0A2',
#                  'L3Z 0C1',
#                  'L3Z 0J2',
#                  'L3Z 0X2',
#                  'L3Z 1T7',
#                  'L3Z 1Y9',
#                  'L3Z 2A5',
#                  'L3Z 2A8',
#                  'L3Z 2B2',
#                  'L3Z 3H2',
#                  'L4A 1A9',
#                  'L4A 1G3',
#                  'L4A 1N2',
#                  'L4A 1N7',
#                  'L4A 2S8',
#                  'L4A 2Z9',
#                  'L4A 3A1',
#                  'L4A 4J3',
#                  'L4A 4K1',
#                  'L4A 7W6',
#                  'L4A 7X4',
#                  'L4A7X5',
#                  'L4B',
#                  'L4B 0A6',
#                  'L4B 1B2',
#                  'L4B 1J8',
#                  'L4B 1L1',
#                  'L4B 2Y9',
#                  'L4B 3J6',
#                  'L4B 4A7',
#                  'L4B 4N7',
#                  'L4B 4P9',
#                  'L4B 4V9',
#                  'L4C 0R9',
#                  'L4C 1B3',
#                  'L4C 1J9',
#                  'L4C 1N1',
#                  'L4C 1T6',
#                  'L4C 1V4',
#                  'L4C 2M6',
#                  'L4C 3B9',
#                  'L4C 3C9',
#                  'L4C 3E3',
#                  'L4C 5G2',
#                  'L4C 5L8',
#                  'L4C 6Z1',
#                  'L4C 7A1',
#                  'L4C 8S7',
#                  'L4C 8T3',
#                  'L4C 9J2',
#                  'L4C 9X2',
#                  'L4C5E2',
#                  'L4C6Z1',
#                  'L4E 0C9',
#                  'L4E 0L2',
#                  'L4E 0W5',
#                  'L4E 0Z7',
#                  'L4E 1A3',
#                  'L4E 1A5',
#                  'L4E 1B6',
#                  'L4E 2T2',
#                  'L4E 3K2',
#                  'L4E 3L2',
#                  'L4E 3S8',
#                  'L4E 4Z1',
#                  'L4E 5B9',
#                  'L4G 0E1',
#                  'L4G 0E3',
#                  'L4G 0G2',
#                  'L4G 0L8',
#                  'L4G 0S7',
#                  'L4G 1A2',
#                  'L4G 1M7',
#                  'L4G 1N2',
#                  'L4G 1Z8',
#                  'L4G 2B4',
#                  'L4G 2N9',
#                  'L4G 2P4',
#                  'L4G 2X5',
#                  'L4G 3H1',
#                  'L4G 3T3',
#                  'L4G 3V5',
#                  'L4G 4C4',
#                  'L4G 5H2',
#                  'L4G 6H6',
#                  'L4G 7B7',
#                  'L4G 7H8',
#                  'L4G 7J1',
#                  'L4G 7Y3',
#                  'L4G1Z8',
#                  'L4G7C6',
#                  'L4H 0A2',
#                  'L4H 0R9',
#                  'L4H 0S3',
#                  'L4H 1R1',
#                  'L4H 2W8',
#                  'L4H 2X1',
#                  'L4H 2X2',
#                  'L4H 2X3',
#                  'L4H 2X4',
#                  'L4H 2Z7',
#                  'L4H 2Z8',
#                  'L4H 3A2',
#                  'L4H 3A3',
#                  'L4H 3A4',
#                  'L4H 3H5',
#                  'L4H 3H9',
#                  'L4H 3M7',
#                  'L4H 3N5',
#                  'L4H 3T8',
#                  'L4H0A8',
#                  'L4H2J2',
#                  'L4J 0A7',
#                  'L4J 0G9',
#                  'L4J 1A1',
#                  'L4J 1E9',
#                  'L4J 1V7',
#                  'L4J 1V9',
#                  'L4J 2L1',
#                  'L4J 2P6',
#                  'L4J 4E5',
#                  'L4J 4P8',
#                  'L4J 5K2',
#                  'L4J 5S3',
#                  'L4J 6X3',
#                  'L4J 7L2',
#                  'L4J 7R4',
#                  'L4J 7X3',
#                  'L4J 8A7',
#                  'L4J 8B2',
#                  'L4J 8C7',
#                  'L4J 8G3',
#                  'L4J 8L7',
#                  'L4J 8M5',
#                  'L4J 8S1',
#                  'L4J 8V3',
#                  'L4J 8V6',
#                  'L4J 8W5',
#                  'L4J 8Z9',
#                  'L4J 9A2',
#                  'L4J 9E3',
#                  'L4J 9K7',
#                  'L4J8A4',
#                  'L4K',
#                  'L4K 0A2',
#                  'L4K 0B1',
#                  'L4K 1K8',
#                  'L4K 1R9',
#                  'L4K 1V5',
#                  'L4K 2K7',
#                  'L4K 2M9',
#                  'L4K 2N6',
#                  'L4K 2Y7',
#                  'L4K 2Z5',
#                  'L4K 3M4',
#                  'L4K 3T8',
#                  'L4K 3Y8',
#                  'L4K 3Z6',
#                  'L4K 4B6',
#                  'L4K 4J7',
#                  'L4K 4V8',
#                  'L4K 5R3',
#                  'L4K 5R6',
#                  'L4K 5R7',
#                  'L4K 5W4',
#                  'L4K 5X8',
#                  'L4K 5Z7',
#                  'L4K0A2',
#                  'L4L 1A5',
#                  'L4L 1A6',
#                  'L4L 1A7',
#                  'L4L 1L2',
#                  'L4L 1S6',
#                  'L4L 1S8',
#                  'L4L 3W4',
#                  'L4L 4S5',
#                  'L4L 4Y5',
#                  'L4L 6B1',
#                  'L4L 6H3',
#                  'L4L 7N7',
#                  'L4L 8A3',
#                  'L4L 8B8',
#                  'L4L 8N6',
#                  'L4L 8R1',
#                  'L4L 9E4',
#                  'L4L 9E7',
#                  'L4L 9J8',
#                  'L4L 9J9',
#                  'L4L 9K5',
#                  'L4L 9R4',
#                  'L4L 9T1',
#                  'L4S 0B2',
#                  'L4S 0B6',
#                  'L4S 1A2',
#                  'L4S 1N5',
#                  'L4S 1P3',
#                  'L4S 1S7',
#                  'L4S 2K9',
#                  'L4S1P3',
#                  'L4S2N5',
#                  'L4T 1A1',
#                  'L4T 1A8',
#                  'L4T 1A9',
#                  'L4T 1T5',
#                  'L4T 1Y2',
#                  'L4T 4E3',
#                  'L4T 4J3',
#                  'L4V 1C9',
#                  'L4V 1E4',
#                  'L4V 1R3',
#                  'L4V 1T1',
#                  'L4V 1V3',
#                  'L4V 1X6',
#                  'L4V 1Y3',
#                  'L4V1E1',
#                  'L4V1N1',
#                  'L4V1T2',
#                  'L4W 0B3',
#                  'L4W 1B9',
#                  'L4W 1C4',
#                  'L4W 1G5',
#                  'L4W 1J8',
#                  'L4W 1W9',
#                  'L4W 1Y1',
#                  'L4W 1Y2',
#                  'L4W 2A4',
#                  'L4W 2S1',
#                  'L4W 2S5',
#                  'L4W 2T7',
#                  'L4W 3Z1',
#                  'L4W 3Z4',
#                  'L4W 4G1',
#                  'L4W 4J4',
#                  'L4W 4K4',
#                  'L4W 4Y1',
#                  'L4W 4Y5',
#                  'L4W 5C7',
#                  'L4W 5G3',
#                  'L4W 5J7',
#                  'L4W 5L2',
#                  'L4W 5N6',
#                  'L4W 5P6',
#                  'L4W1E9',
#                  'L4W1J1',
#                  'L4W1K3',
#                  'L4W1S9',
#                  'L4W1V2',
#                  'L4W1V5',
#                  'L4W2B9',
#                  'L4W2P7',
#                  'L4W2R1',
#                  'L4W2Z7',
#                  'L4W3Z3',
#                  'L4W4G1',
#                  'L4W4L8',
#                  'L4W4M1',
#                  'L4W4T4',
#                  'L4W4V8',
#                  'L4W4Y5',
#                  'L4W5A6',
#                  'L4W5G6',
#                  'L4W5M4',
#                  'L4X 1B5',
#                  'L4X 1K1',
#                  'L4X 1K9',
#                  'L4X 1L3',
#                  'L4X 1S5',
#                  'L4X 2J4',
#                  'L4X 2J6',
#                  'L4X 2Z2',
#                  'L4X 2Z8',
#                  'L4X1L4',
#                  'L4X1L5',
#                  'L4X1L9',
#                  'L4X2E2',
#                  'L4X2W7',
#                  'L4X2X1',
#                  'L4X2Z3',
#                  'L4Y 1A9',
#                  'L4Y 1M4',
#                  'L4Y 2C1',
#                  'L4Y 2H5',
#                  'L4Y 2H6',
#                  'L4Y 2N6',
#                  'L4Y 2W4',
#                  'L4Y 2X3',
#                  'L4Y 3B7',
#                  'L4Y 3J1',
#                  'L4Y 3P5',
#                  'L4Y 4B2',
#                  'L4Y 4E2',
#                  'L4Y1A6',
#                  'L4Y1Y6',
#                  'L4Y2B8',
#                  'L4Y2C1',
#                  'L4Y2C2',
#                  'L4Z 0A9',
#                  'L4Z 1H2',
#                  'L4Z 1K2',
#                  'L4Z 1N9',
#                  'L4Z 1S1',
#                  'L4Z 1S2',
#                  'L4Z 1S6',
#                  'L4Z 1V9',
#                  'L4Z 1Z5',
#                  'L4Z 2C2',
#                  'L4Z 2G2',
#                  'L4Z 2Z1',
#                  'L4Z 3C3',
#                  'L4Z 3L9',
#                  'L4Z 3M2',
#                  'L4Z 3V1',
#                  'L4Z 3W7',
#                  'L4Z1H8',
#                  'L4Z1N5',
#                  'L4Z1P3',
#                  'L4Z1W7',
#                  'L4Z2H3',
#                  'L4Z3K8',
#                  'L4Z3V5',
#                  'L4w4M6',
#                  'L4z 2c2',
#                  'L5A 0A1',
#                  'L5A 1V1',
#                  'L5A 1V9',
#                  'L5A 1W8',
#                  'L5A 1W9',
#                  'L5A 1Z3',
#                  'L5A 2N3',
#                  'L5A 2X1',
#                  'L5A 2Y5',
#                  'L5A 3C9',
#                  'L5A 3E5',
#                  'L5A 3K6',
#                  'L5A 3M9',
#                  'L5A 3V9',
#                  'L5A 3Y1',
#                  'L5A 4K3',
#                  'L5A 4K4',
#                  'L5A1B2',
#                  'L5A1S2',
#                  'L5A1W8',
#                  'L5A2P1',
#                  'L5A3V9',
#                  'L5B 1H9',
#                  'L5B 1N1',
#                  'L5B 1W5',
#                  'L5B 2C9',
#                  'L5B 2M7',
#                  'L5B 2N5',
#                  'L5B 2T4',
#                  'L5B 3C1',
#                  'L5B 3R1',
#                  'L5B 3R2',
#                  'L5B 3W7',
#                  'L5B 4C1',
#                  'L5B 4J3',
#                  'L5B 4L1',
#                  'L5B 4L2',
#                  'L5B 4M4',
#                  'L5B1B5',
#                  'L5B1B6',
#                  'L5B2C9',
#                  'L5C 1H7',
#                  'L5C 1J5',
#                  'L5C 1T3',
#                  'L5C 1V8',
#                  'L5C 1X2',
#                  'L5C 1Y5',
#                  'L5C 1Y7',
#                  'L5C 2M9',
#                  'L5C 2T3',
#                  'L5C 2Y7',
#                  'L5C 3B4',
#                  'L5C 3B6',
#                  'L5C 4G4',
#                  'L5C1C3',
#                  'L5C1Y2',
#                  'L5C1Z4',
#                  'L5C2V1',
#                  'L5C3P5',
#                  'L5C3Y8',
#                  'L5E 1C8',
#                  'L5E 1G4',
#                  'L5E 1G5',
#                  'L5E 1H5',
#                  'L5E 1V4',
#                  'L5E 2C1',
#                  'L5E 2G1',
#                  'L5E 2L7',
#                  'L5E 2P8',
#                  'L5E 2V4',
#                  'L5E 2X4',
#                  'L5E 2X9',
#                  'L5E 2Z9',
#                  'L5E 3H7',
#                  'L5E 3H9',
#                  'L5E 3J9',
#                  'L5E 3K2',
#                  'L5E 3K7',
#                  'L5E1E2',
#                  'L5E1E3',
#                  'L5E1E4',
#                  'L5E1E5',
#                  'L5E1E6',
#                  'L5E3G2',
#                  'L5G 1C9',
#                  'L5G 1E1',
#                  'L5G 1G1',
#                  'L5G 1G2',
#                  'L5G 1H2',
#                  'L5G 1K1',
#                  'L5G 1T1',
#                  'L5G 2B6',
#                  'L5G 2R9',
#                  'L5G 2T3',
#                  'L5G 2V8',
#                  'L5G 3B5',
#                  'L5G 3H2',
#                  'L5G 3H6',
#                  'L5G 3H9',
#                  'L5G 3Z1',
#                  'L5G 4A6',
#                  'L5G 4B2',
#                  'L5G 4J6',
#                  'L5G 4N1',
#                  'L5G 4N4',
#                  'L5G 4R7',
#                  'L5G1E2',
#                  'L5G1E9',
#                  'L5G1G1',
#                  'L5G1G8',
#                  'L5G1H3',
#                  'L5G1H4',
#                  'L5G1H9',
#                  'L5G3R2',
#                  'L5G4S6',
#                  'L5H 1E9',
#                  'L5H 2K4',
#                  'L5H1E9',
#                  'L5H1G6',
#                  'L5H1G8',
#                  'L5H2C4',
#                  'L5H3B1',
#                  'L5J 1H3',
#                  'L5J 1J4',
#                  'L5J 1J5',
#                  'L5J 1J7',
#                  'L5J 1K5',
#                  'L5J 2W7',
#                  'L5J 2Y4',
#                  'L5J 2Z1',
#                  'L5J1J4',
#                  'L5J1J5',
#                  'L5J1J6',
#                  'L5J1J7',
#                  'L5J1K5',
#                  'L5J4S8',
#                  'L5K 1K8',
#                  'L5K 1P9',
#                  'L5K 1R2',
#                  'L5K 2K4',
#                  'L5K 2L8',
#                  'L5K 2M6',
#                  'L5K1R8',
#                  'L5L 1C6',
#                  'L5L 1G5',
#                  'L5L 2V8',
#                  'L5L 2Z3',
#                  'L5L 3N1',
#                  'L5L 3P9',
#                  'L5L 3R1',
#                  'L5L 3R4',
#                  'L5L 3R8',
#                  'L5L 4L4',
#                  'L5L 4X9',
#                  'L5L 5K2',
#                  'L5L 5M8',
#                  'L5L 5X8',
#                  'L5L 5Y3',
#                  'L5L 5Y5',
#                  'L5L 5Z5',
#                  'L5L 5Z6',
#                  'L5L 5Z7',
#                  'L5L 6A5',
#                  'L5L 6B1',
#                  'L5L3R8',
#                  'L5L4X5',
#                  'L5L5Z5',
#                  'L5M 0R4',
#                  'L5M 1G3',
#                  'L5M 1N2',
#                  'L5M 1W1',
#                  'L5M 1Y4',
#                  'L5M 2J5',
#                  'L5M 4L9',
#                  'L5M 4Z5',
#                  'L5M 4Z9',
#                  'L5M 5G8',
#                  'L5M 6B5',
#                  'L5M 6J3',
#                  'L5M0H1',
#                  'L5M1L4',
#                  'L5M1L9',
#                  'L5M5K5',
#                  'L5M6J3',
#                  'L5N 1P9',
#                  'L5N 1Z6',
#                  'L5N 2L8',
#                  'L5N 4B7',
#                  'L5N 5A7',
#                  'L5N 5M2',
#                  'L5N 6A6',
#                  'L5N 6C1',
#                  'L5N 6H7',
#                  'L5N 6R4',
#                  'L5N 6R7',
#                  'L5N 7H5',
#                  'L5N 7J9',
#                  'L5N 7K6',
#                  'L5N 7L7',
#                  'L5N 8C8',
#                  'L5N 8G4',
#                  'L5N 8P6',
#                  'L5N 8P7',
#                  'L5N1P7',
#                  'L5N2L8',
#                  'L5N6A3',
#                  'L5N7L7',
#                  'L5N7Y5',
#                  'L5R 0B7',
#                  'L5R 1Y3',
#                  'L5R 2N3',
#                  'L5R 3B5',
#                  'L5R 3E7',
#                  'L5R 3V2',
#                  'L5R 3X9',
#                  'L5R 3Z1',
#                  'L5R 4C1',
#                  'L5R 4G2',
#                  'L5R 4G6',
#                  'L5R4G6',
#                  'L5S 1M7',
#                  'L5S 1M9',
#                  'L5S 1Z1',
#                  'L5S1E9',
#                  'L5S1X7',
#                  'L5T 1K4',
#                  'L5T 1K8',
#                  'L5T 1L6',
#                  'L5T 1M9',
#                  'L5T 2A5',
#                  'L5T 2B8',
#                  'L5T 2K7',
#                  'L5T 2N8',
#                  'L5T0A4',
#                  'L5T1X3',
#                  'L5T2V8',
#                  'L5V 0A7',
#                  'L5V 1N3',
#                  'L5V 2A8',
#                  'L5V 2M6',
#                  'L5V 2N6',
#                  'L5V 2P3',
#                  'L5V 3B7',
#                  'L5V0B7',
#                  'L5V2N6',
#                  'L5V2X8',
#                  'L5V3B7',
#                  'L5W 1C7',
#                  'L5W 1G3',
#                  'L5W 1L9',
#                  'L5W 1R6',
#                  'L5W0E6',
#                  'L5W1L9',
#                  'L5l2r4',
#                  'L67 0A7',
#                  'L6A 0S1',
#                  'L6A 1A8',
#                  'L6A 1L7',
#                  'L6A 1S2',
#                  'L6A 1Y3',
#                  'L6A 3B1',
#                  'L6A 4K5',
#                  'L6A 4N7',
#                  'L6A 4N9',
#                  'L6B 0P2',
#                  'L6B 0P4',
#                  'L6B 1A8',
#                  'L6B 1B4',
#                  'L6B 1B5',
#                  'L6B 1E8',
#                  'L6C 0A2',
#                  'L6C 0J4',
#                  'L6C 0Y2',
#                  'L6C 1N9',
#                  'L6C 1P8',
#                  'L6C 1S7',
#                  'L6C 1Y9',
#                  'L6C 2P9',
#                  'L6C 2Z8',
#                  'L6C 3H6',
#                  'L6C1K8',
#                  'L6E 0H7',
#                  'L6E 0K3',
#                  'L6E 0N1',
#                  'L6E 1A1',
#                  'L6E 1G4',
#                  'L6E 1H8',
#                  'L6E 1N7',
#                  'L6E 1T5',
#                  'L6E 1X1',
#                  'L6E 2G1',
#                  'L6E0K9',
#                  'L6G 0A2',
#                  'L6G 0A6',
#                  'L6G 0A9',
#                  'L6G 0E3',
#                  'L6G 0E4',
#                  'L6G 0E7',
#                  'L6G 0G1',
#                  'L6G 1B3',
#                  'L6H 0C3',
#                  'L6H 0E7',
#                  'L6H 0G6',
#                  'L6H 3H6',
#                  'L6H 3N8',
#                  'L6H 3P1',
#                  'L6H 4K4',
#                  'L6H 4L5',
#                  'L6H 5M8',
#                  'L6H 6C8',
#                  'L6H 6P5',
#                  'L6H 6W4',
#                  'L6H2R9',
#                  'L6H6M2',
#                  'L6H7G5',
#                  'L6H7G6',
#                  'L6J 1J1',
#                  'L6J 3J3',
#                  'L6J 3L6',
#                  'L6J 3M5',
#                  'L6J 4V5',
#                  'L6J 5W5',
#                  'L6J 7C8',
#                  'L6J 7E6',
#                  'L6J 7L4',
#                  'L6J 7L6',
#                  'L6J 7S8',
#                  'L6J3J1',
#                  'L6J7R4',
#                  'L6K 2H4',
#                  'L6K 3A7',
#                  'L6K 3B9',
#                  'L6K 3E1',
#                  'L6K 3P1',
#                  'L6K3Y6',
#                  'L6L 0B7',
#                  'L6L 2C3',
#                  'L6L 2X5',
#                  'L6L 4G2',
#                  'L6L 4N4',
#                  'L6L 5A8',
#                  'L6L 5M2',
#                  'L6L 6A4',
#                  'L6L 6L7',
#                  'L6L 6P7',
#                  'L6L5B3',
#                  'L6L5B5',
#                  'L6M 0L9',
#                  'L6M 0M1',
#                  'L6M 0M2',
#                  'L6M 0M3',
#                  'L6M 0T9',
#                  'L6M 1S2',
#                  'L6M 2G2',
#                  'L6M 2V7',
#                  'L6M 3W6',
#                  'L6M 4M1',
#                  'L6M 4M2',
#                  'L6M 4P1',
#                  'L6M 5A9',
#                  'L6M0C2',
#                  'L6M4E2',
#                  'L6P 0A2',
#                  'L6P 0A6',
#                  'L6P 0B1',
#                  'L6P 0B6',
#                  'L6P 1A1',
#                  'L6P 2B1',
#                  'L6P 2G7',
#                  'L6P 2P7',
#                  'L6P 3X3',
#                  'L6P1E7',
#                  'L6P1W3',
#                  'L6P2R1',
#                  'L6P2S4',
#                  'L6P2S5',
#                  'L6P2Z8',
#                  'L6P3A3',
#                  'L6R 0C2',
#                  'L6R 0W1',
#                  'L6R 0W9',
#                  'L6R 1A2',
#                  'L6R 1J1',
#                  'L6R 1J3',
#                  'L6R 1W0',
#                  'L6R 1W4',
#                  'L6R 2K7',
#                  'L6R 2W5',
#                  'L6R 2Z4',
#                  'L6R 3A4',
#                  'L6R 3P4',
#                  'L6R0E1',
#                  'L6R0J9',
#                  'L6R0M5',
#                  'L6R0W9',
#                  'L6R1T4',
#                  'L6R1W4',
#                  'L6R1W7',
#                  'L6R3G2',
#                  'L6R3S9',
#                  'L6S 0E2',
#                  'L6S 0X5',
#                  'L6S 1G3',
#                  'L6S 2N3',
#                  'L6S 3L6',
#                  'L6S 3R2',
#                  'L6S 3Y5',
#                  'L6S 4B1',
#                  'L6S 4B7',
#                  'L6S 5M4',
#                  'L6S 6G3',
#                  'L6S 6G6',
#                  'L6S 6L1',
#                  'L6S0B8',
#                  'L6S0C6',
#                  'L6S3Y5',
#                  'L6S4B4',
#                  'L6S5M4',
#                  'L6T 0H4',
#                  'L6T 1B4',
#                  'L6T 1V9',
#                  'L6T 1X3',
#                  'L6T 1X5',
#                  'L6T 1Z1',
#                  'L6T 2C9',
#                  'L6T 2E4',
#                  'L6T 2Y9',
#                  'L6T 3M5',
#                  'L6T 3P1',
#                  'L6T 3P5',
#                  'L6T 3R5',
#                  'L6T 4E9',
#                  'L6T 4K4',
#                  'L6T 4M9',
#                  'L6T 4W5',
#                  'L6T 5A8',
#                  'L6T 5B9',
#                  'L6T 5C8',
#                  'L6T 5H5',
#                  'L6T 5H8',
#                  'L6T 5L5',
#                  'L6T 5L6',
#                  'L6T 5M3',
#                  'L6T 5M4',
#                  'L6T 5N9',
#                  'L6T 5P1',
#                  'L6T 5W2',
#                  'L6T 6A3',
#                  'L6T0E2',
#                  'L6T2W8',
#                  'L6T3R5',
#                  'L6T4W2',
#                  'L6T5P9',
#                  'L6V 1A2',
#                  'L6V 1B9',
#                  'L6V 1C2',
#                  'L6V 1C3',
#                  'L6V 1G9',
#                  'L6V 1N2',
#                  'L6V 1V1',
#                  'L6V 1V6',
#                  'L6V 1W2',
#                  'L6V 1X4',
#                  'L6V 1X8',
#                  'L6V 2A1',
#                  'L6V 3V6',
#                  'L6V 3V9',
#                  'L6V 3W6',
#                  'L6V 4L5',
#                  'L6V 4P3',
#                  'L6V 4T3',
#                  'L6V1N2',
#                  'L6V1N6',
#                  'L6V4K2',
#                  'L6W 1H4',
#                  'L6W 1P9',
#                  'L6W 2B3',
#                  'L6W 2B6',
#                  'L6W 2B8',
#                  'L6W 2C4',
#                  'L6W 2E2',
#                  'L6W 2G7',
#                  'L6W 3J1',
#                  'L6W 3J3',
#                  'L6W 3T7',
#                  'L6W 4P9',
#                  'L6W 4S1',
#                  'L6W0B4',
#                  'L6W2B5',
#                  'L6W2E1',
#                  'L6W4P5',
#                  'L6X 0B3',
#                  'L6X 0G9',
#                  'L6X 0S1',
#                  'L6X 1M9',
#                  'L6X 3P1',
#                  'L6X 4T7',
#                  'L6X 5A5',
#                  'L6X 5C1',
#                  'L6X0B3',
#                  'L6X0S1',
#                  'L6X1M8',
#                  'L6X1M9',
#                  'L6Y 0B5',
#                  'L6Y 0B8',
#                  'L6Y 0E9',
#                  'L6Y 1J2',
#                  'L6Y 1L9',
#                  'L6Y 1N9',
#                  'L6Y 1R1',
#                  'L6Y 1Z4',
#                  'L6Y 2C8',
#                  'L6Y 2X4',
#                  'L6Y 4G1',
#                  'L6Y 4M3',
#                  'L6Y 4T6',
#                  'L6Y 5B6',
#                  'L6Y 5J8',
#                  'L6Y 5P4',
#                  'L6Y 5S5',
#                  'L6Y0B8',
#                  'L6Y0M2',
#                  'L6Y0M4',
#                  'L6Y0Y3',
#                  'L6Y1N7',
#                  'L6Z 0E4',
#                  'L6Z 1X9',
#                  'L6Z 1Y1',
#                  'L6Z 2Z7',
#                  'L6Z 3X3',
#                  'L6Z0E3',
#                  'L6Z1Y4',
#                  'L6Z2S6',
#                  'L6Z3L5',
#                  'L6Z3S4',
#                  'L6Z4R3',
#                  'L6k2G3',
#                  'L6r Oj6',
#                  'L7A 0A1',
#                  'L7A 0E7',
#                  'L7A 0G2',
#                  'L7A 0H2',
#                  'L7A 0M8',
#                  'L7A 1A7',
#                  'L7A 1A8',
#                  'L7A 1E6',
#                  'L7A 1M8',
#                  'L7A 2X9',
#                  'L7A 2Z7',
#                  'L7A 3R9',
#                  'L7A2G8',
#                  'L7A2X6',
#                  'L7A2Z3',
#                  'L7A3Z6',
#                  'L7B 0C6',
#                  'L7B 0L9',
#                  'L7B 0N1',
#                  'L7B 1A2',
#                  'L7B 1A3',
#                  'L7B 1A6',
#                  'L7B 1A8',
#                  'L7B 1C9',
#                  'L7B 1G2',
#                  'L7B 1G3',
#                  'L7B 1G4',
#                  'L7B 1H1',
#                  'L7B 1H5',
#                  'L7B 1H7',
#                  'L7B 1H8',
#                  'L7B 1J2',
#                  'L7B 1K2',
#                  'L7B 1K5',
#                  'L7B 1L1',
#                  'L7B 1L5',
#                  'L7B 1L6',
#                  'L7B 1M3',
#                  'L7C 0K7',
#                  'L7C 0S1',
#                  'L7C 0W5',
#                  'L7C 0Z5',
#                  'L7C 1E6',
#                  'L7C 1H8',
#                  'L7C 1H9',
#                  'L7C 1N3',
#                  'L7C 1W8',
#                  'L7C 2A1',
#                  'L7C 2H9',
#                  'L7C 2J3',
#                  'L7C 2L7',
#                  'L7C 2P9',
#                  'L7C 2T7',
#                  'L7C 2V5',
#                  'L7C 2X6',
#                  'L7C 2Z2',
#                  'L7C 3E6',
#                  'L7C 3K7',
#                  'L7C 3L8',
#                  'L7C1M3',
#                  'L7C1X1',
#                  'L7E 0L2',
#                  'L7E 0M1',
#                  'L7E 0T8',
#                  'L7E 0T9',
#                  'L7E 0Y4',
#                  'L7E 1A1',
#                  'L7E 1A2',
#                  'L7E 1C7',
#                  'L7E 1C8',
#                  'L7E 1M3',
#                  'L7E 1M7',
#                  'L7E 1T6',
#                  'L7E 2B4',
#                  'L7E 2V2',
#                  'L7E 2V9',
#                  'L7E 2Z7',
#                  'L7E 3P6',
#                  'L7E 4G1',
#                  'L7E 4G6',
#                  'L7E 4Z5',
#                  'L7E 5T3',
#                  'L7E 5T4',
#                  'L7E0W1',
#                  'L7E1C1',
#                  'L7E4Z7',
#                  'L7G 0J1',
#                  'L7G 0L5',
#                  'L7G 2H6',
#                  'L7G 2X3',
#                  'L7G 3E4',
#                  'L7G 4A1',
#                  'L7G 4A9',
#                  'L7G 4B1',
#                  'L7G 4B5',
#                  'L7G 4G4',
#                  'L7G 4R7',
#                  'L7G 4S4',
#                  'L7G 4S6',
#                  'L7G 4T1',
#                  'L7G 4X5',
#                  'L7G 5G2',
#                  'L7G 5S7',
#                  'L7G2S4',
#                  'L7G3T1',
#                  'L7G4S4',
#                  'L7J 0A5',
#                  'L7J 1B9 ',
#                  'L7J 1C1',
#                  'L7J 1G7',
#                  'L7J 1H1',
#                  'L7J 1H2',
#                  'L7J 1P6',
#                  'L7J 1R2',
#                  'L7J 1W1',
#                  'L7J 1Z3',
#                  'L7J 2',
#                  'L7J 2E6',
#                  'L7J 2L2',
#                  'L7J 2L8',
#                  'L7J 2N2',
#                  'L7J 2N3',
#                  'L7K 0A4',
#                  'L7K 0A8',
#                  'L7K 0C2',
#                  'L7K 0C3',
#                  'L7K 0C4',
#                  'L7K 0E8',
#                  'L7K 0G7',
#                  'L7K 0R1',
#                  'L7K 0S3',
#                  'L7K 0S5',
#                  'L7K 0V8',
#                  'L7K 0X8',
#                  'L7K 0Y2',
#                  'L7K 0Y6',
#                  'L7K 1W3',
#                  'L7K 1X1',
#                  'L7K0A1',
#                  'L7K0E7',
#                  'L7K0W7',
#                  'L7K0W9',
#                  'L7K0X4',
#                  'L7K0Y3',
#                  'L7L 0A2',
#                  'L7L 0B6',
#                  'L7L 0B7',
#                  'L7L 0G5',
#                  'L7L 0J3',
#                  'L7L 1V3',
#                  'L7L 3V4',
#                  'L7L 3V7',
#                  'L7L 3V8',
#                  'L7L 3W4',
#                  'L7L 3W5',
#                  'L7L 3X7',
#                  'L7L 3X8',
#                  'L7L 3Y2',
#                  'L7L 4K5',
#                  'L7L 4X4',
#                  'L7L 4Y8',
#                  'L7L 5H9',
#                  'L7L 5L1',
#                  'L7L 5M4',
#                  'L7L 5M9',
#                  'L7L 5N3',
#                  'L7L 5P9',
#                  'L7L 5Y6',
#                  'L7L 6A1',
#                  'L7L 6A6',
#                  'L7L 6C7',
#                  'L7L 6M5',
#                  'L7L 6M6',
#                  'L7L 7H7',
#                  'L7L 7L6',
#                  'L7L1C7',
#                  'L7L5H9',
#                  'L7L7J8',
#                  'L7M',
#                  'L7M 0N6',
#                  'L7M 0N9',
#                  'L7M 0V5',
#                  'L7M 0W3',
#                  'L7M 0W4',
#                  'L7M 1A9',
#                  'L7M 1M2',
#                  'L7M 4A6',
#                  'L7M 4M8',
#                  'L7M 5A5',
#                  'L7M4A5',
#                  'L7M4A6',
#                  'L7M4A7',
#                  'L7M4A9',
#                  'L7M4B8',
#                  'L7N 1M5',
#                  'L7N 1M8',
#                  'L7N 2G3',
#                  'L7N 2M3',
#                  'L7N 2R4',
#                  'L7N 3G7',
#                  'L7N 3J3',
#                  'L7N4X7',
#                  'L7P 0B4',
#                  'L7P 0J1',
#                  'L7P 0J7',
#                  'L7P 1H4',
#                  'L7P 1X7',
#                  'L7P 1X8',
#                  'L7P 3G9',
#                  'L7P 3X1',
#                  'L7P 5A5',
#                  'L7P 5C7',
#                  'L7P1S9',
#                  'L7P2H5',
#                  'L7P3N8',
#                  'L7R 0A4',
#                  'L7R 0A6',
#                  'L7R 0B2',
#                  'L7R 0B4',
#                  'L7R 1B1',
#                  'L7R 1E1',
#                  'L7R 1E9',
#                  'L7R 1H1',
#                  'L7R 1J2',
#                  'L7R 1J4',
#                  'L7R 1K5',
#                  'L7R 1K8',
#                  'L7R 1T8',
#                  'L7R 2E1',
#                  'L7R 2E3',
#                  'L7R 2E4',
#                  'L7R 2E9',
#                  'L7R 2G3',
#                  'L7R 2G4',
#                  'L7R 2G6',
#                  'L7R 2J4',
#                  'L7R 2J5',
#                  'L7R 2M8',
#                  'L7R 2N1',
#                  'L7R 2N4',
#                  'L7R 2P7',
#                  'L7R 2X2',
#                  'L7R 2X3',
#                  'L7R 2Y2',
#                  'L7R 2Y4',
#                  'L7R 3L7',
#                  'L7R 3L8',
#                  'L7R 3L9',
#                  'L7R 3M2',
#                  'L7R 3M7',
#                  'L7R 3N2',
#                  'L7R 3N5',
#                  'L7R 3N6',
#                  'L7R 3R3',
#                  'L7R 3T3',
#                  'L7R 3X4',
#                  'L7R 3X5',
#                  'L7R 3Y3',
#                  'L7R 3Z6',
#                  'L7R 4C2',
#                  'L7R 4C7',
#                  'L7R 4G2',
#                  'L7R 4J4',
#                  'L7S 1B1',
#                  'L7S 1B5',
#                  'L7S 1P7',
#                  'L7S 1T7',
#                  'L7S 1V1',
#                  'L7S 1W4',
#                  'L7S 1W6',
#                  'L7S 2J8',
#                  'L7S 2K2',
#                  'L7S 2K4',
#                  'L7S 2L8',
#                  'L7T 0A4',
#                  'L7T 2C3',
#                  'L7T 3Z7',
#                  'L7T 4K1',
#                  'L7T2B9',
#                  'L8E 2H3',
#                  'L8E 2L1',
#                  'L8E 2P2',
#                  'L8E 2W1',
#                  'L8E 2W8',
#                  'L8E 5C5',
#                  'L8E 5J3',
#                  'L8E 5K7',
#                  'L8E 5M8',
#                  'L8E 6H2',
#                  'L8G 1B6',
#                  'L8G 1C1',
#                  'L8G 1C3',
#                  'L8G 1G4',
#                  'L8G 3H9',
#                  'L8G 4H8',
#                  'L8G 5E5',
#                  'L8G 5G3',
#                  'L8H 1W2',
#                  'L8H 2T8',
#                  'L8H 2V1',
#                  'L8H 2V2',
#                  'L8H 2W6',
#                  'L8H 3Z5',
#                  'L8K 1V8',
#                  'L8K 1V9',
#                  'L8K 2N8',
#                  'L8K 3E5',
#                  'L8L 0A9',
#                  'L8L 1H1',
#                  'L8L 1Z6',
#                  'L8L 2V6',
#                  'L8L 2W5',
#                  'L8L 2X2',
#                  'L8L 3A9',
#                  'L8L 3X3',
#                  'L8L 5W8',
#                  'L8L 6B4',
#                  'L8L 6Y7',
#                  'L8L 7M5',
#                  'L8M 1K2',
#                  'L8M2K9',
#                  'L8N 1A3',
#                  'L8N 1B7',
#                  'L8N 1E2',
#                  'L8N 1K1',
#                  'L8N 1P2',
#                  'L8N 1P6',
#                  'L8N 2B9',
#                  'L8N 2C6',
#                  'L8N 2W1',
#                  'L8N 2W6',
#                  'L8N 2Z7',
#                  'L8N 3W8',
#                  'L8P 0B3',
#                  'L8P 1A2',
#                  'L8P 1A9',
#                  'L8P 1B1',
#                  'L8P 1P9',
#                  'L8P 1W8',
#                  'L8P 2C7',
#                  'L8P 2N9',
#                  'L8P 2S8',
#                  'L8P 2Z4',
#                  'L8P 3M7',
#                  'L8P 3T6',
#                  'L8P 4B9',
#                  'L8P 4M4',
#                  'L8P 4R5',
#                  'L8P 4W3',
#                  'L8P 4Y5',
#                  'L8R 0A1',
#                  'L8R 1G6',
#                  'L8R 1N7',
#                  'L8R 1N8',
#                  'L8R 1N9',
#                  'L8R 1P1',
#                  'L8R 2L3',
#                  'L8R 2R5',
#                  'L8R 2S5',
#                  'L8R 2S6',
#                  'L8R 2S7',
#                  'L8R 2Y5',
#                  'L8R 2Y6',
#                  'L8R 3H5',
#                  'L8R 3J6',
#                  'L8R 3L4',
#                  'L8S 1A1',
#                  'L8S 1C6',
#                  'L8S 1G5',
#                  'L8S 1K6',
#                  'L8S 1L7',
#                  'L8S 3S1',
#                  'L8S 3T3',
#                  'L8S 4J7',
#                  'L8S 4K1',
#                  'L8T 1B4',
#                  'L8T 1P9',
#                  'L8T 4M9',
#                  'L8T 4Y4',
#                  'L8T1J4',
#                  'L8V 1C9',
#                  'L8V 1H5',
#                  'L8V 1H9',
#                  'L8V 1T9',
#                  'L8V 1W9',
#                  'L8V 4H8',
#                  'L8V 4L7',
#                  'L8W 1T9',
#                  'L8W 1Z6',
#                  'L8W1C4',
#                  'L9&5M3',
#                  'L9A 2N5',
#                  'L9A 3M8',
#                  'L9A 3P5',
#                  'L9A 3P9',
#                  'L9A 3R1',
#                  'L9A 4X5',
#                  'L9C 1R3',
#                  'L9C 1X6',
#                  'L9C 2Y9',
#                  'L9C 2Z1',
#                  'L9C 3B3',
#                  'L9C 4H2',
#                  'L9C 4S9',
#                  'L9C 4T2',
#                  'L9C 5E4',
#                  'L9C 5R8',
#                  'L9C 6C2',
#                  'L9C 7B7',
#                  'L9C 7B9',
#                  'L9G 1N1',
#                  'L9G 1N2',
#                  'L9G 3J4',
#                  'L9G 3K9',
#                  'L9G 5E3',
#                  'L9G2C1',
#                  'L9H 0C1',
#                  'L9H 1T5',
#                  'L9H 1V4',
#                  'L9H 1W9',
#                  'L9H 2H4',
#                  'L9H 4A7',
#                  'L9H 4B6',
#                  'L9H 4H4',
#                  'L9H 4V1',
#                  'L9H 4Y9',
#                  'L9H 5E1',
#                  'L9H 5E2',
#                  'L9H 5E3',
#                  'L9H 5M4',
#                  'L9H 7P6',
#                  'L9H 7S6',
#                  'L9H 7S7',
#                  'L9H 7S8',
#                  'L9H 7S9',
#                  'L9K 1J9',
#                  'L9K 1L6',
#                  'L9L 1B2',
#                  'L9L 1B3',
#                  'L9L 1B5',
#                  'L9L 1H8',
#                  'L9L 1J4',
#                  'L9L 1K2',
#                  'L9L 1K6',
#                  'L9L 1N5',
#                  'L9L 1Z3',
#                  'L9L1P5',
#                  'L9N 0H2',
#                  'L9N 0H9',
#                  'L9N 1L8',
#                  'L9P 0E5',
#                  'L9P 1A1',
#                  'L9P 1C5',
#                  'L9P 1C7',
#                  'L9P 1G1',
#                  'L9P 1J5',
#                  'L9P 1K5',
#                  'L9P 1M6',
#                  'L9P 1N1',
#                  'L9P 1N4',
#                  'L9P 1P5',
#                  'L9P 1R1',
#                  'L9P 1R4',
#                  'L9P 1S9',
#                  'L9P 1Y4',
#                  'L9P 1Z7',
#                  'L9P1B4',
#                  'L9P1P7',
#                  'L9R 0E9',
#                  'L9R 1G7',
#                  'L9R 1G9',
#                  'L9R 1K1',
#                  'L9R 1K4',
#                  'L9R 1K6',
#                  'L9R 1V1',
#                  'L9T 0A5',
#                  'L9T 0J9',
#                  'L9T 1P7',
#                  'L9T 1Y4',
#                  'L9T 2X8',
#                  'L9T 2Z4',
#                  'L9T 3Z3',
#                  'L9T 4R3',
#                  'L9T 6K2',
#                  'L9T 6N7',
#                  'L9T 7X1',
#                  'L9T 8K4',
#                  'L9T0R3',
#                  'L9T2G5',
#                  'L9T2R3',
#                  'L9T2T1',
#                  'L9T2X5',
#                  'L9T6N2',
# ...
#                  'M6J 1V1',
#                  'M6J 1V3',
#                  'M6J 1W3',
#                  'M6J 1X2',
#                  'M6J 1X3',
#                  'M6J 1X5',
#                  'M6J 2A4',
#                  'M6J 2K6',
#                  'M6J 2L3',
#                  'M6J 2X5',
#                  'M6J 2Z5',
#                  'M6J 3A5',
#                  'M6J 3H2',
#                  'M6J 3L2',
#                  'M6J 3S7',
#                  'M6J1G3',
#                  'M6K',
#                  'M6K 0A5',
#                  'M6K 0B3',
#                  'M6K 0C2',
#                  'M6K 1A9',
#                  'M6K 1B6',
#                  'M6K 1E4',
#                  'M6K 1G2',
#                  'M6K 1G3',
#                  'M6K 1G4',
#                  'M6K 1L3',
#                  'M6K 1L7',
#                  'M6K 1L8',
#                  'M6K 1L9',
#                  'M6K 1M1',
#                  'M6K 1M2',
#                  'M6K 1M3',
#                  'M6K 1M4',
#                  'M6K 1S9',
#                  'M6K 1W8',
#                  'M6K 2J1',
#                  'M6K 2R8',
#                  'M6K 2V3',
#                  'M6K 2V4',
#                  'M6K 2V6',
#                  'M6K 2Y3',
#                  'M6K 3C3',
#                  'M6K 3C5',
#                  'M6K 3C7',
#                  'M6K 3E1',
#                  'M6K 3E3',
#                  'M6K 3L2',
#                  'M6K 3P2',
#                  'M6K 3P3',
#                  'M6L 1L7',
#                  'M6L 1N4',
#                  'M6L 2E5',
#                  'M6L 2V4',
#                  'M6L 3C9',
#                  'M6L3E2',
#                  'M6M 1B9',
#                  'M6M 1T9',
#                  'M6M 2E1',
#                  'M6M 2E6',
#                  'M6M 2V6',
#                  'M6M 2Y8',
#                  'M6M 3P1',
#                  'M6M 3W5',
#                  'M6M 3X7',
#                  'M6M 4G9',
#                  'M6M 5E6',
#                  'M6M 5H6',
#                  'M6M4N8',
#                  'M6N 1A5',
#                  'M6N 1C7',
#                  'M6N 1H7',
#                  'M6N 1K9',
#                  'M6N 1L2',
#                  'M6N 1P8',
#                  'M6N 1S9',
#                  'M6N 1T6',
#                  'M6N 1W9',
#                  'M6N 2H8',
#                  'M6N 2K1',
#                  'M6N 2T7',
#                  'M6N 2Z4',
#                  'M6N 3K2',
#                  'M6N 3P4',
#                  'M6N 3P7',
#                  'M6N 3X3',
#                  'M6N 4A7',
#                  'M6N 4E2',
#                  'M6N 4R1',
#                  'M6N 4R8',
#                  'M6N 4Y9',
#                  'M6N 4Z2',
#                  'M6N 5C2',
#                  'M6N 5H4',
#                  'M6N5G4',
#                  'M6P 0A1',
#                  'M6P 0A6',
#                  'M6P 1B2',
#                  'M6P 1C9',
#                  'M6P 1E2',
#                  'M6P 1G5',
#                  'M6P 1G7',
#                  'M6P 1G8',
#                  'M6P 1G9',
#                  'M6P 1J5',
#                  'M6P 1L5',
#                  'M6P 1M6',
#                  'M6P 1P3',
#                  'M6P 1R3',
#                  'M6P 1T8',
#                  'M6P 1W7',
#                  'M6P 1W9',
#                  'M6P 1X2',
#                  'M6P 1Y1',
#                  'M6P 1Y5',
#                  'M6P 1Y8',
#                  'M6P 1Y9',
#                  'M6P 1Z3',
#                  'M6P 1Z4',
#                  'M6P 1Z7',
#                  'M6P 1Z8',
#                  'M6P 2A4',
#                  'M6P 2K6',
#                  'M6P 2L5',
#                  'M6P 2P3',
#                  'M6P 2R1',
#                  'M6P 2S1',
#                  'M6P 2V1',
#                  'M6P 2V3',
#                  'M6P 2V5',
#                  'M6P 2V8',
#                  'M6P 2V9',
#                  'M6P 2W1',
#                  'M6P 2W4',
#                  'M6P 2W5',
#                  'M6P 2W6',
#                  'M6P 2W7',
#                  'M6P 2W8',
#                  'M6P 2W9',
#                  'M6P 2X1',
#                  'M6P 2Y7',
#                  'M6P 2Z1',
#                  'M6P 3E3',
#                  'M6P 3G3',
#                  'M6P 3G4',
#                  'M6P 3G5',
#                  'M6P 3G7',
#                  'M6P 3G8',
#                  'M6P 3H5',
#                  'M6P 3H6',
#                  'M6P 3H7',
#                  'M6P 3H8',
#                  'M6P 3H9',
#                  'M6P 3J1',
#                  'M6P 3J2',
#                  'M6P 3J3',
#                  'M6P 3K8',
#                  'M6P 3N4',
#                  'M6P 3P8',
#                  'M6P 3S5',
#                  'M6P 3X9',
#                  'M6P 4A9',
#                  'M6P 4B4',
#                  'M6P 4H5',
#                  'M6P 4J6',
#                  'M6P1A5',
#                  'M6P1J6',
#                  'M6P4A9',
#                  'M6R 1A1',
#                  'M6R 1B4',
#                  'M6R 1K3',
#                  'M6R 1M9',
#                  'M6R 1T2',
#                  'M6R 1W9',
#                  'M6R 1X1',
#                  'M6R 1X3',
#                  'M6R 1Y9',
#                  'M6R 2E2',
#                  'M6R 2J1',
#                  'M6R 2K6',
#                  'M6R 2M3',
#                  'M6R 2M7',
#                  'M6R 2M8',
#                  'M6R 2N1',
#                  'M6R 3A9',
#                  'M6R2K3',
#                  'M6S 1N2',
#                  'M6S 1N6',
#                  'M6S 1N9',
#                  'M6S 1P3',
#                  'M6S 1P4',
#                  'M6S 1P5',
#                  'M6S 1P9',
#                  'M6S 1V2',
#                  'M6S 1X8',
#                  'M6S 1Y1',
#                  'M6S 1Y4',
#                  'M6S 1Y5',
#                  'M6S 1Y6',
#                  'M6S 2A1',
#                  'M6S 2C2',
#                  'M6S 2C8',
#                  'M6S 2E2',
#                  'M6S 2E4',
#                  'M6S 2H7',
#                  'M6S 2M2',
#                  'M6S 2S1',
#                  'M6S 2S5',
#                  'M6S 2Y7',
#                  'M6S 2Y8',
#                  'M6S 3J9',
#                  'M6S 3P2',
#                  'M6S 3P6',
#                  'M6S 3R4',
#                  'M6S 3Z2',
#                  'M6S 4A3',
#                  'M6S 4A6',
#                  'M6S 4G9',
#                  'M6S 4P4',
#                  'M6S 4W6',
#                  'M6S 5B5',
#                  'M6S1N7',
#                  'M6S2K3',
#                  'M6S4W6',
#                  'M8V 1K2',
#                  'M8V 1K3',
#                  'M8V 1K6',
#                  'M8V 1L2',
#                  'M8V 1L8',
#                  'M8V 1M6',
#                  'M8V 1R4',
#                  'M8V 1Y8',
#                  'M8V 2E8',
#                  'M8V 2X4',
#                  'M8V 2Z3',
#                  'M8V 3B5',
#                  'M8V 3L1',
#                  'M8V 3M1',
#                  'M8V 3N1',
#                  'M8V 3W6',
#                  'M8V 3W7',
#                  'M8V 3X7',
#                  'M8V 4A2',
#                  'M8V 4C5',
#                  'M8V0B8',
#                  'M8V1H5',
#                  'M8V1J2',
#                  'M8V1K2',
#                  'M8V1K5',
#                  'M8V1L4',
#                  'M8V3Z2',
#                  'M8W 0A3',
#                  'M8W 1N6',
#                  'M8W 1P7',
#                  'M8W 2C2',
#                  'M8W 2K7',
#                  'M8W 2S1',
#                  'M8W 2W6',
#                  'M8W 3E9',
#                  'M8W 3G7',
#                  'M8W 3S3',
#                  'M8W 3T5',
#                  'M8W 3T6',
#                  'M8W1N2',
#                  'M8W1N5',
#                  'M8W1N6',
#                  'M8W1P4',
#                  'M8W1P9',
#                  'M8W1R2',
#                  'M8W2B3',
#                  'M8W3T5',
#                  'M8W3T7',
#                  'M8W3W2',
#                  'M8X 0A5',
#                  'M8X 1A5',
#                  'M8X 1C2',
#                  'M8X 1C3',
#                  'M8X 1E2',
#                  'M8X 1E9',
#                  'M8X 1G4',
#                  'M8X 1K8',
#                  'M8X 1R1',
#                  'M8X 1R2',
#                  'M8X 1R8',
#                  'M8X 1T1',
#                  'M8X 1T3',
#                  'M8X 2A3',
#                  'M8X 2L5',
#                  'M8X 2M6',
#                  'M8X 2V3',
#                  'M8X 2Y4',
#                  'M8X1A9',
#                  'M8X1M3',
#                  'M8X1P9',
#                  'M8Y 1B7',
#                  'M8Y 1G4',
#                  'M8Y 1H6',
#                  'M8Y 1K5',
#                  'M8Y 1P7',
#                  'M8Y 1R8',
#                  'M8Y 1T3',
#                  'M8Y 1Z6',
#                  'M8Y 2G4',
#                  'M8Y 2K2',
#                  'M8Y 2M2',
#                  'M8Y 2N3',
#                  'M8Y 2T1',
#                  'M8Y 2T3',
#                  'M8Y 3C7',
#                  'M8Y 3H8',
#                  'M8Y 3J7',
#                  'M8Y 3J8',
#                  'M8Y 3J9',
#                  'M8Y 3L3',
#                  'M8Y 3P7',
#                  'M8Y 3X1',
#                  'M8Y 3X6',
#                  'M8Y 4A4',
#                  'M8Y 4B3',
#                  'M8Y 4B6',
#                  'M8Y 4H5',
#                  'M8Y1J2',
#                  'M8Y1J3',
#                  'M8Z 0B9',
#                  'M8Z 1V1',
#                  'M8Z 1V4',
#                  'M8Z 2J4',
#                  'M8Z 2R1',
#                  'M8Z 2R9',
#                  'M8Z 2S6',
#                  'M8Z 2Y1',
#                  'M8Z 4R9',
#                  'M8Z 4T5',
#                  'M8Z 4V7',
#                  'M8Z 5G5',
#                  'M8Z 5J3',
#                  'M8Z 5K7',
#                  'M8Z 5T1',
#                  'M8Z 5X2',
#                  'M8Z 6C7',
#                  'M8Z1N5',
#                  'M8Z1N7',
#                  'M8Z1R6',
#                  'M8Z1T8',
#                  'M8Z2G9',
#                  'M8Z2R4',
#                  'M8Z2Z4',
#                  'M8Z2Z8',
#                  'M8Z5G8',
#                  'M9A 1A2',
#                  'M9A 1A9',
#                  'M9A 1B2',
#                  'M9A 1B6',
#                  'M9A 1N4',
#                  'M9A 1P4',
#                  'M9A 2H5',
#                  'M9A 2J1',
#                  'M9A 2J9',
#                  'M9A 2P7',
#                  'M9A 3E1',
#                  'M9A 3L8',
#                  'M9A 3N2',
#                  'M9A 3N5',
#                  'M9A 3N7',
#                  'M9A 4X6',
#                  'M9A 4X7',
#                  'M9A 4Y1',
#                  'M9A 5E7',
#                  'M9A1C2',
#                  'M9A1C4',
#                  'M9A3V3',
#                  'M9B 1J1',
#                  'M9B 1L3',
#                  'M9B 1M5',
#                  'M9B 1V1',
#                  'M9B 1a9',
#                  'M9B 2A9',
#                  'M9B 2B1',
#                  'M9B 2C4',
#                  'M9B 2E4',
#                  'M9B 2R5',
#                  'M9B 2Y7',
#                  'M9B 3G7',
#                  'M9B 3G8',
#                  'M9B 3R6',
#                  'M9B 3W7',
#                  'M9B 3Y8',
#                  'M9B 3Z9',
#                  'M9B 4N3',
#                  'M9B 5K1',
#                  'M9B 5Y7',
#                  'M9B 6A4',
#                  'M9B 6E1',
#                  'M9B 6H6',
#                  'M9B 6H7',
#                  'M9B 6J1',
#                  'M9B 6L5',
#                  'M9B 6M1',
#                  'M9B1L1',
#                  'M9B1L3',
#                  'M9B2A8',
#                  'M9B3Z8',
#                  'M9C',
#                  'M9C 1A8',
#                  'M9C 1B8',
#                  'M9C 1C6',
#                  'M9C 1Y2',
#                  'M9C 1Y5',
#                  'M9C 1Y9',
#                  'M9C 2H3',
#                  'M9C 2N6',
#                  'M9C 2P7',
#                  'M9C 3G6',
#                  'M9C 3S8',
#                  'M9C 3T3',
#                  'M9C 3T8',
#                  'M9C 4R3',
#                  'M9C 4S5',
#                  'M9C 4Z6',
#                  'M9C 5H5',
#                  'M9C 5M1',
#                  'M9C1A8',
#                  'M9C3S6',
#                  'M9C4Z6',
#                  'M9C5H5',
#                  'M9G 6H6',
#                  'M9L 1A2',
#                  'M9L 1N4',
#                  'M9L 1X9',
#                  'M9L 2A6',
#                  'M9L 2C1',
#                  'M9L 2G9',
#                  'M9M 1A9',
#                  'M9M 1S3',
#                  'M9M 2A8',
#                  'M9M 2C7',
#                  'M9M 2L4',
#                  'M9M 2L7',
#                  'M9M 2V9',
#                  'M9M2G3',
#                  'M9N 1K2',
#                  'M9N 1K9',
#                  'M9N 1W2',
#                  'M9N 1X4',
#                  'M9N 1X7',
#                  'M9N 2B3',
#                  'M9N 2M1',
#                  'M9N 2Y9',
#                  'M9N 3A8',
#                  'M9N 3V9',
#                  'M9P 1E9',
#                  'M9P 1N8',
#                  'M9P 2E8',
#                  'M9P 3B6',
#                  'M9P 3M7',
#                  'M9P 3N3',
#                  'M9P 3P1',
#                  'M9R',
#                  'M9R 1H4',
#                  'M9R 1K8',
#                  'M9R 1V8',
#                  'M9R 2K4',
#                  'M9R 2K5',
#                  'M9R 2K6',
#                  'M9R 2R5',
#                  'M9R 2R7',
#                  'M9R 2Y1',
#                  'M9R 3C8',
#                  'M9R 3H1',
#                  'M9R 3T9',
#                  'M9R 3V7',
#                  'M9R 4A3',
#                  'M9R 4B3',
#                  'M9V 0A1',
#                  'M9V 1T1',
#                  'M9V 1V9',
#                  'M9V 2C9',
#                  'M9V 2E3',
#                  'M9V 2E9',
#                  'M9V 3B2',
#                  'M9V 3J4',
#                  'M9V 3L5',
#                  'M9V 3M5',
#                  'M9V 3R4',
#                  'M9V 3S3',
#                  'M9V 3S4',
#                  'M9V 3S9',
#                  'M9V 3Y6',
#                  'M9V 3Z5',
#                  'M9V 5C7',
#                  'M9W 0A2',
#                  'M9W 1A2',
#                  'M9W 1B3',
#                  'M9W 1J1',
#                  'M9W 1J3',
#                  'M9W 1V4',
#                  'M9W 2H8',
#                  'M9W 2K4',
#                  'M9W 2K5',
#                  'M9W 2K7',
#                  'M9W 2N8',
#                  'M9W 2P9',
#                  'M9W 2S6',
#                  'M9W 2S7',
#                  'M9W 2S8',
#                  'M9W 2S9',
#                  'M9W 2T1',
#                  'M9W 2T4',
#                  'M9W 3W6',
#                  'M9W 3W7',
#                  'M9W 4A6',
#                  'M9W 4A7',
#                  'M9W 4C9',
#                  'M9W 4K8',
#                  'M9W 4K9',
#                  'M9W 4L2',
#                  'M9W 4S7',
#                  'M9W 5E8',
#                  'M9W 5G1',
#                  'M9W 5K7',
#                  'M9W 5L7',
#                  'M9W 5N4',
#                  'M9W 5P3',
#                  'M9W 5R1',
#                  'M9W 6A5',
#                  'M9W 6A6',
#                  'M9W 6A7',
#                  'M9W 6J6',
#                  'M9W 6K5',
#                  'M9W 6N5',
#                  'M9W 6P3',
#                  'M9W 6P4',
#                  'M9W 6P5',
#                  'M9W 6P6',
#                  'M9W 6P7',
#                  'M9W 6R2',
#                  'M9W 6R6',
#                  'M9W 6R7',
#                  'M9W 6V5',
#                  'M9W 6V6',
#                  'M9W 7A6',
#                  'M9W 7C8',
#                  'M9W 7J2',
#                  'M9W 7K5',
#                  'M9W1J8',
#                  'M9W7K7',
#                  'N0B 1L0',
#                  'N0B 1T0',
#                  'N0B 1Z0',
#                  'N0B 2K0',
#                  'N0B-1T0',
#                  'N1H 6H7',
#                  'N1H 6H9',
#                  'N1H6H9',
#                  'N3C 4V4',
#                  'N4X2P9',
#                  'ON L5G 4V6',
#                  'l3Y 3J2',
#                  'l4l8r1',
#                  'l6c2t2',
#                  'l6p 2r1',
#                  'l7a 3r9',
#                  'l8g 3p1',
#                  'l8h 1t8',
#                  'l9t 5h6',
#                  'm1g2l6',
#                  'm2l 2k4',
#                  'm3j 2n7',
#                  'm4x 1a6',
#                  'm5v1m1',
#                  'm9b1b6',
#                  'm9l 2t6',
#                  'n3r 5l8'])}

# %%
6. Auditing for the inconsistent phone numbers or format

# %%
# Compiler for cleaning phone format 
phone_type_re = re.compile(r'\d{3}\)?-?\s?.?\d{3}\s?-?\s?.?\d{4}')
phone_re = re.compile('\.|\)|\s|-')

def audit_phone_type(phone_types, phone):
    m = phone_type_re.search(phone)
    if m:
        phone_type = m.group()
        if phone_type not in phone_types:
            new_phone = phone_re.sub('',phone_type)
            new_phone = ('+1-' + new_phone[:3] + '-' +
                         new_phone[3:6] + '-' + new_phone[6:])
            phone_types[new_phone].add(phone)
    else:
        phone_types['unknown'].add(phone)
        
def is_phone(elem):
    return (elem.attrib['k'] == "phone")

def phone_audit(osmfile):
    osm_file = open(osmfile, "r")    
    phone_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):
        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_phone(tag):
                    audit_phone_type(phone_types, tag.attrib['v'])                
    osm_file.close()
    return phone_types
    
phones_types = phone_audit(OSM_FILE_UPDATED_PC)
# To validate or check the phone numbers format after the changes, uncomment the next line and comment the above one
#phones_types = phone_audit(OSM_FILE_UPDATED_PH) 

pprint.pprint(dict(phones_types))

OSM_FILE_UPDATED_PH = "toronto_canada3.osm"

# Following function update phone numbers to the correct format 

def u_phone(phone):
    m = phone_type_re.search(phone)
    if m:
        new_phone = phone_re.sub('', m.group())
        return ('+1-' + new_phone[:3] + '-' + new_phone[3:6] +
                '-' + new_phone[6:])        
    else:
        return phone

# This function replace the incosistent phone numbers with the right format

def update_phone(original_file, update_file):
    with open(update_file, 'wb') as output:
        output.write('<?xml version="1.0" encoding="UTF-8"?>\n')
        output.write('<osm>\n  ') 
        for i, element in enumerate(get_element(original_file)):
            for tag in element.iter("tag"):
                if is_phone(tag):
                    tag.set('v',u_phone(tag.attrib['v']))
            output.write(ET.tostring(element, encoding='utf-8'))
        output.write('</osm>')

update_phone(OSM_FILE_UPDATED_PC, OSM_FILE_UPDATED_PH)
# Out:
# {'+1-128-993-89380': set(['+12899389380']),
#  '+1-128-999-70644': set(['12899970644']),
#  '+1-141-621-40008': set(['14162140008']),
#  '+1-141-624-39362': set(['+14162439362']),
#  '+1-141-625-11144': set(['+14162511144']),
#  '+1-141-629-30404': set(['+14162930404']),
#  '+1-141-629-87917': set(['+14162987917']),
#  '+1-141-631-42901': set(['+14163142901']),
#  '+1-141-635-17065': set(['+14163517065']),
#  '+1-141-636-10331': set(['14163610331']),
#  '+1-141-636-17454': set(['+14163617454']),
#  '+1-141-636-40054': set(['+14163640054']),
#  '+1-141-636-70633': set(['+14163670633']),
#  '+1-289-633-3624': set(['+1 289 633-3624']),
#  '+1-289-635-5586': set(['289-635-5586']),
#  '+1-289-649-1111': set(['289-649-1111']),
#  '+1-289-660-2761': set(['289-660-2761']),
#  '+1-289-660-6066': set(['+1 289 660-6066']),
#  '+1-289-689-5409': set(['289 689 5409']),
#  '+1-289-724-0528': set(['+1 289 724-0528']),
#  '+1-289-725-0000': set(['+1 289-725-0000']),
#  '+1-289-725-0338': set(['+1 289-725-0338']),
#  '+1-289-725-7815': set(['+1 289-725-7815']),
#  '+1-289-725-8686': set(['289-725-8686']),
#  '+1-289-725-9887': set(['+1 289-725-9887']),
#  '+1-289-725-9988': set(['+1 289-725-9988']),
#  '+1-289-768-4758': set(['(289) 768-4758']),
#  '+1-289-796-1155': set(['289-796-1155']),
#  '+1-289-804-3636': set(['1-289-804-3636']),
#  '+1-289-806-2049': set(['2898062049']),
#  '+1-289-807-0700': set(['1-289-807-0700']),
#  '+1-289-813-0099': set(['+1 289 813-0099']),
#  '+1-289-814-4415': set(['+1 289-814-4415']),
#  '+1-289-837-0443': set(['289-837-0443']),
#  '+1-289-837-1193': set(['+1 289 837-1193']),
#  '+1-289-837-3021': set(['289-837-3021']),
#  '+1-289-837-3056': set(['+1 289 837-3056']),
#  '+1-289-848-9188': set(['+1 289 848-9188']),
#  '+1-289-851-9329': set(['+1 289 851-9329']),
#  '+1-289-851-9353': set(['+1 289 851-9353']),
#  '+1-289-878-1901': set(['289-878-1901']),
#  '+1-289-878-2222': set(['289-878-2222']),
#  '+1-289-878-2400': set(['289-878-2400']),
#  '+1-289-878-4244': set(['+1 289-878-4244']),
#  '+1-289-878-5987': set(['+1 289 878-5987']),
#  '+1-289-878-7489': set(['+1 289 878-7489']),
#  '+1-289-887-2835': set(['289 887 2835']),
#  '+1-289-901-0964': set(['+1 289-901-0964']),
#  '+1-289-917-5782': set(['+1 289-917-5782']),
#  '+1-289-923-7299': set(['+1-289-923-7299']),
#  '+1-289-961-0730': set(['+1 289 961 0730']),
#  '+1-289-971-5639': set(['289-971-5639']),
#  '+1-289-971-6261': set(['+1 289 971-6261']),
#  '+1-289-981-8066': set(['+1 289 981-8066']),
#  '+1-289-988-4004': set(['289-988-4004']),
#  '+1-289-997-1470': set(['+1 289-997-1470']),
#  '+1-289-997-2108': set(['+1 289 997-2108']),
#  '+1-415-255-4414': set(['415-255-4414']),
#  '+1-415-255-8858': set(['415-255-8858']),
#  '+1-416-201-0115': set(['416-201-0115']),
#  '+1-416-201-0200': set(['416-201-0200']),
#  '+1-416-201-0606': set(['+1 416 201-0606']),
#  '+1-416-201-6969': set(['+1 416-201-6969']),
#  '+1-416-201-8221': set(['+1 416 201-8221']),
#  '+1-416-201-8411': set(['+1 416 201 8411']),
#  '+1-416-201-8718': set(['416-201-8718']),
#  '+1-416-201-9087': set(['416-201-9087']),
#  '+1-416-201-9491': set(['+1 416- 201-9491']),
#  '+1-416-201-9515': set(['+1 416 201 9515']),
#  '+1-416-203-0178': set(['416-203-0178']),
#  '+1-416-203-1233': set(['(416)203-1233']),
#  '+1-416-222-9112': set(['416-222-9112']),
#  '+1-416-223-2453': set(['416-223-2453']),
#  '+1-416-223-3162': set(['4162233162']),
#  '+1-416-223-8338': set(['416-223-8338']),
#  '+1-416-223-9300': set(['416-223-9300 ext. 223']),
#  '+1-416-224-0540': set(['416-224-0540']),
#  '+1-416-224-1100': set(['+1 416-224-1100']),
#  '+1-416-224-2600': set(['+1 416 224 2600']),
#  '+1-416-224-5595': set(['416-224-5595']),
#  '+1-416-225-1666': set(['416-225-1666']),
#  '+1-416-225-2112': set(['(416) 225-2112']),
#  '+1-416-225-2623': set(['4162252623']),
#  '+1-416-225-2679': set(['416-225-2679']),
#  '+1-416-225-4949': set(['416-225-4949']),
#  '+1-416-225-5313': set(['+1 416 225 5313']),
#  '+1-416-225-7777': set(['+1 416 225 7777']),
#  '+1-416-226-0111': set(['416-226-0111']),
#  '+1-416-226-0404': set(['+1 416 226 0404']),
#  '+1-416-226-2286': set(['(416) 226-2286']),
#  '+1-416-226-3200': set(['(416) 226-3200']),
#  '+1-416-226-3700': set(['416-226-3700']),
#  '+1-416-226-4411': set(['4162264411']),
#  '+1-416-226-5557': set(['+1 416 226 5557']),
#  '+1-416-226-9122': set(['(416) 226-9122']),
#  '+1-416-227-1168': set(['+1 416 227 1168']),
#  '+1-416-227-9650': set(['416-227-9650']),
#  '+1-416-231-0443': set(['416-231-0443']),
#  '+1-416-231-1367': set(['+1 416 231 1367']),
#  '+1-416-231-1717': set(['+1 416 231-1717']),
#  '+1-416-231-3167': set(['+1 416-231-3167']),
#  '+1-416-231-3266': set(['+1 416 231-3266']),
#  '+1-416-231-3387': set(['+1 416 231-3387']),
#  '+1-416-231-3663': set(['+1 416 231-3663']),
#  '+1-416-231-4014': set(['416-231-4014']),
#  '+1-416-231-5335': set(['+1 416-231-5335']),
#  '+1-416-231-6300': set(['+1 416-231-6300']),
#  '+1-416-231-6483': set(['416-231-6483']),
#  '+1-416-231-6916': set(['+1 416 231-6916']),
#  '+1-416-231-7743': set(['+1 416-231-7743']),
#  '+1-416-231-7895': set(['+1 416 231 7895']),
#  '+1-416-231-8002': set(['416-231-8002']),
#  '+1-416-231-8064': set(['416-231-8064']),
#  '+1-416-231-9163': set(['+1 416 231-9163']),
#  '+1-416-231-9502': set(['416-231-9502']),
#  '+1-416-232-0211': set(['+1 416 232-0211']),
#  '+1-416-232-0222': set(['+1 416-232-0222']),
#  '+1-416-232-0997': set(['+1 416-232-0997']),
#  '+1-416-232-2320': set(['416-232-2320']),
#  '+1-416-232-2702': set(['+1 416-232-2702']),
#  '+1-416-233-0404': set(['+1 416-233-0404']),
#  '+1-416-233-0733': set(['416-233-0733']),
#  '+1-416-233-2011': set(['+1 416-233-2011']),
#  '+1-416-233-2210': set(['+1 416 233-2210']),
#  '+1-416-233-2847': set(['4162332847']),
#  '+1-416-233-3233': set(['416-233-3233']),
#  '+1-416-233-4227': set(['416-233-4227']),
#  '+1-416-233-6276': set(['+1 416-233-6276']),
#  '+1-416-233-6761': set(['+1 416 233-6761']),
#  '+1-416-233-7088': set(['+1 416-233-7088']),
#  '+1-416-233-9111': set(['+1 416 233-9111']),
#  '+1-416-233-9581': set(['+1 416-233-9581']),
#  '+1-416-234-0011': set(['416-234-0011']),
#  '+1-416-234-0404': set(['416-234-0404']),
#  '+1-416-234-0601': set(['+1 416 234 0601']),
#  '+1-416-234-1160': set(['+1 416-234-1160']),
#  '+1-416-234-1736': set(['+1 416 234 1736']),
#  '+1-416-234-2231': set(['416-234-2231']),
#  '+1-416-234-2233': set(['+1 416-234-2233']),
#  '+1-416-234-2290': set(['4162342290']),
#  '+1-416-234-2886': set(['+1 416-234-2886']),
#  '+1-416-234-5073': set(['+1 416 234-5073']),
#  '+1-416-234-8060': set(['+1 416-234-8060']),
#  '+1-416-234-8666': set(['+1 416-234-8666']),
#  '+1-416-234-9911': set(['+1 416 234-9911']),
#  '+1-416-235-1500': set(['+1 416-235-1500']),
#  '+1-416-235-2888': set(['(416) 235-2888']),
#  '+1-416-236-0036': set(['(416) 236-0036']),
#  '+1-416-236-0543': set(['+1 416 236 0543']),
#  '+1-416-236-0677': set(['+1 416 236-0677']),
#  '+1-416-236-1131': set(['+1 416 2361131']),
#  '+1-416-236-1175': set(['+1 416-236-1175']),
#  '+1-416-236-1596': set(['+1-416-236-1596']),
#  '+1-416-236-2221': set(['416-236-2221']),
#  '+1-416-236-2627': set(['+1-416-236-2627']),
#  '+1-416-236-2641': set(['(416) 236-2641']),
#  '+1-416-236-2867': set(['+1 416-236-2867']),
#  '+1-416-236-3183': set(['+1 416-236-3183']),
#  '+1-416-236-3217': set(['+1 416 236 3217']),
#  '+1-416-236-5086': set(['+1 416-236-5086']),
#  '+1-416-236-5535': set(['+1 416-236-5535']),
#  '+1-416-236-8888': set(['416-236-8888']),
#  '+1-416-237-0557': set(['+1 416-237-0557']),
#  '+1-416-237-9900': set(['416-237-9900']),
#  '+1-416-239-0585': set(['+1 416-239-0585']),
#  '+1-416-239-1114': set(['+1 416-239-1114']),
#  '+1-416-239-1259': set(['416-239-1259']),
#  '+1-416-239-2341': set(['+1 416 239-2341']),
#  '+1-416-239-2824': set(['416-239-2824']),
#  '+1-416-239-4393': set(['+1 416-239-4393']),
#  '+1-416-239-4410': set(['+1 416-239-4410']),
#  '+1-416-239-4800': set(['+1 416 239-4800']),
#  '+1-416-239-5380': set(['416-239-5380']),
#  '+1-416-239-5990': set(['+1 416-239-5990']),
#  '+1-416-239-6068': set(['416-239-6068']),
#  '+1-416-239-6206': set(['+1 416 2396206']),
#  '+1-416-239-7090': set(['+1 416 239 7090']),
#  '+1-416-240-0110': set(['4162400110']),
#  '+1-416-240-0707': set(['+1 416 240 0707']),
#  '+1-416-240-0915': set(['4162400915']),
#  '+1-416-240-1988': set(['416-240-1988']),
#  '+1-416-240-7000': set(['+1 416 240 7000']),
#  '+1-416-240-7511': set(['416-240-7511']),
#  '+1-416-240-8728': set(['+1 416 240 8728']),
#  '+1-416-240-9090': set(['+1 (416) 240-9090', '416-240-9090']),
#  '+1-416-240-9741': set(['+1 416-240-9741']),
#  '+1-416-300-8800': set(['+1 416-300-8800']),
#  '+1-416-301-7586': set(['+1 416 301-7586']),
#  '+1-416-302-0907': set(['+1 416 302 0907']),
#  '+1-416-302-1133': set(['+1 416 302 1133']),
#  '+1-416-304-1147': set(['416-304-1147']),
#  '+1-416-304-4224': set(['(416) 304-4224']),
#  '+1-416-304-9482': set(['416-304-9482']),
#  '+1-416-306-0311': set(['+1 416 306 0311']),
#  '+1-416-306-0335': set(['416-306-0335']),
#  '+1-416-306-0779': set(['+1-416-306-0779']),
#  '+1-416-306-5800': set(['416-306-5800']),
#  '+1-416-308-5888': set(['(416) 308-5888']),
#  '+1-416-314-5899': set(['(416) 314-5899']),
#  '+1-416-319-9448': set(['+1 416 319 9448']),
#  '+1-416-321-3590': set(['+1 416 321 3590']),
#  '+1-416-321-8800': set(['416-321-8800']),
#  '+1-416-322-2198': set(['+1 416 322 2198']),
#  '+1-416-322-2881': set(['(416) 322-2881']),
#  '+1-416-322-4886': set(['416-322-4886']),
#  '+1-416-322-5155': set(['416-322-5155']),
#  '+1-416-322-6184': set(['4163226184']),
#  '+1-416-322-6668': set(['416-322-6668']),
#  '+1-416-322-7000': set(['416-322-7000']),
#  '+1-416-322-7050': set(['416-322-7050']),
#  '+1-416-322-7091': set(['+1 416 322 7091']),
#  '+1-416-322-7137': set(['416-322-7137']),
#  '+1-416-322-7707': set(['+1 416 322 7707']),
#  '+1-416-322-8858': set(['416-322-8858']),
#  '+1-416-322-8861': set(['416-322-8861']),
#  '+1-416-322-9079': set(['416-322-9079']),
#  '+1-416-322-9999': set(['416-322-9999']),
#  '+1-416-323-0100': set(['+1 416 323 0100']),
#  '+1-416-323-0178': set(['4163230178']),
#  '+1-416-323-0666': set(['(416) 323-0666']),
#  '+1-416-323-3333': set(['416-323-3333']),
#  '+1-416-323-3456': set(['416-323-3456']),
#  '+1-416-323-3663': set(['416-323-3663']),
#  '+1-416-323-5092': set(['416-323-5092']),
#  '+1-416-323-9212': set(['+1 416-323-9212']),
#  '+1-416-323-9770': set(['416-323-9770']),
#  '+1-416-324-9425': set(['4163249425']),
#  '+1-416-324-9979': set(['416-324-9979']),
#  '+1-416-327-6997': set(['+1-416--327-6997', '+1-416-327-6997']),
#  '+1-416-331-8686': set(['+1 416 331 8686']),
#  '+1-416-331-9701': set(['+1 416 331 9701']),
#  '+1-416-335-0040': set(['+1 416 335 0040']),
#  '+1-416-335-5122': set(['416-335-5122']),
#  '+1-416-340-1254': set(['416-340-1254']),
#  '+1-416-340-2667': set(['1-416-340-2667']),
#  '+1-416-340-7111': set(['+1 416 340 7111']),
#  '+1-416-340-7154': set(['+1-416-340-7154']),
#  '+1-416-340-9386': set(['(416) 340-9386', '+1 416 340 9386']),
#  '+1-416-341-0888': set(['+1 416-341-0888']),
#  '+1-416-341-7100': set(['(416) 341-7100']),
#  '+1-416-343-1234': set(['(416) 343-1234', '416 343 1234']),
#  '+1-416-347-4971': set(['+1 416 347 4971']),
#  '+1-416-348-0982': set(['+1-416-348-0982']),
#  '+1-416-422-4383': set(['+1 416 422 4383']),
#  '+1-416-422-4682': set(['416-422-4682']),
#  '+1-416-422-5353': set(['+1 416 422 5353']),
#  '+1-416-422-5920': set(['416-422-5920']),
#  '+1-416-423-1644': set(['416-423-1644']),
#  '+1-416-423-3222': set(['+1 416 423 3222']),
#  '+1-416-423-3475': set(['416-423-3475']),
#  '+1-416-423-4419': set(['416-423-4419']),
#  '+1-416-424-2078': set(['416-424-2078']),
#  '+1-416-424-3368': set(['+1 416 424 3368']),
#  '+1-416-425-0487': set(['416-425-0487']),
#  '+1-416-425-1253': set(['4164251253']),
#  '+1-416-425-2261': set(['416-425-2261']),
#  '+1-416-425-2895': set(['+1 416 425 2895']),
#  '+1-416-425-3565': set(['416-425-3565']),
#  '+1-416-425-5144': set(['416-425-5144']),
#  '+1-416-425-5516': set(['+1 416 425 5516']),
#  '+1-416-425-7866': set(['416-425-7866']),
#  '+1-416-425-8383': set(['416-425-8383']),
#  '+1-416-425-8800': set(['+1 416 425 8800']),
#  '+1-416-425-9119': set(['416-425-9119']),
#  '+1-416-429-0783': set(['+1 416 429 0783']),
#  '+1-416-429-1550': set(['+1 416-429-1550']),
#  '+1-416-429-2562': set(['416-429-2562']),
#  '+1-416-429-2929': set(['416-429-2929']),
#  '+1-416-429-3296': set(['416-429-3296']),
#  '+1-416-429-3317': set(['+1 416 429 3317']),
#  '+1-416-429-3663': set(['416-429-3663']),
#  '+1-416-429-5687': set(['+1 416 429 5687']),
#  '+1-416-429-7873': set(['+1 416 429 7873']),
#  '+1-416-430-0444': set(['+1 416 430 0444']),
#  '+1-416-431-1020': set(['+1 416 431 1020']),
#  '+1-416-431-3326': set(['416-431-3326']),
#  '+1-416-431-8130': set(['416-431-8130']),
#  '+1-416-434-4322': set(['+1 416 434 4322']),
#  '+1-416-434-4653': set(['416-434-4653']),
#  '+1-416-434-4829': set(['416-434-4829']),
#  '+1-416-438-1452': set(['(416) 438-1452']),
#  '+1-416-438-3344': set(['+1 416 438 3344']),
#  '+1-416-438-7456': set(['416-438-7456']),
#  '+1-416-439-0000': set(['(416) 439-0000',
#                          '+1 416 439-0000',
#                          '+1 416-439-0000',
#                          '1 416 439 0000']),
#  '+1-416-439-5550': set(['416-439-5550']),
#  '+1-416-439-9594': set(['+1 416 439 9594']),
#  '+1-416-440-0077': set(['416-440-0077']),
#  '+1-416-440-0080': set(['416-440-0080']),
#  '+1-416-440-2960': set(['+1 416 440 2960']),
#  '+1-416-441-2273': set(['+1 416 441-2273']),
#  '+1-416-441-2888': set(['416-441-2888']),
#  '+1-416-441-3648': set(['+1 416 441 3648']),
#  '+1-416-443-0795': set(['416-443-0795']),
#  '+1-416-444-2511': set(['416-444-2511']),
#  '+1-416-444-6262': set(['+1 416 444 6262']),
#  '+1-416-444-7223': set(['+1 416 444 7223']),
#  '+1-416-444-7391': set(['+1 416 444 7391']),
#  '+1-416-444-7400': set(['416-444-7400']),
#  '+1-416-444-8444': set(['+1 416 444 8444']),
#  '+1-416-444-8744': set(['+1 416 444 8744']),
#  '+1-416-444-8881': set(['+1 416 444 8881']),
#  '+1-416-445-1015': set(['+1 416 445 1015']),
#  '+1-416-445-1555': set(['416-445-1555']),
#  '+1-416-445-1777': set(['+1 416 445 1777']),
#  '+1-416-445-8868': set(['416-445-8868']),
#  '+1-416-446-1045': set(['416-446-1045']),
#  '+1-416-447-0094': set(['+1 416 447 0094']),
#  '+1-416-447-5963': set(['+1 416 447 5963']),
#  '+1-416-447-7244': set(['+1 416 447 7244']),
#  '+1-416-449-0306': set(['+1 416 449 0306']),
#  '+1-416-449-2420': set(['416-449-2420']),
#  '+1-416-449-3880': set(['+1 416 449 3880']),
#  '+1-416-449-4111': set(['416-449-4111']),
#  '+1-416-449-8342': set(['+1 416 449 8342']),
#  '+1-416-449-9535': set(['416-449-9535']),
#  '+1-416-461-3020': set(['+1 416 461 3020']),
#  '+1-416-461-3970': set(['416-461-3970']),
#  '+1-416-461-5111': set(['416 461 5111']),
#  '+1-416-461-7500': set(['(416) 461-7500']),
#  '+1-416-461-9577': set(['416-461-9577']),
#  '+1-416-462-0064': set(['416-462-0064']),
#  '+1-416-463-3975': set(['+1416-463-3975']),
#  '+1-416-463-4648': set(['416-463-4648']),
#  '+1-416-463-5814': set(['(416) 463-5814']),
#  '+1-416-463-7222': set(['+1 416 463 7222']),
#  '+1-416-463-7678': set(['+1-416-463-7678']),
#  '+1-416-463-8778': set(['416-463-8778']),
#  '+1-416-463-8868': set(['+1 416 463 8868']),
#  '+1-416-463-9979': set(['(416) 463-9979']),
#  '+1-416-464-6018': set(['+1 416 464-6018']),
#  '+1-416-465-4077': set(['(416) 465-4077']),
#  '+1-416-465-4333': set(['416-465-4333']),
#  '+1-416-465-4342': set(['(416) 465-4342']),
#  '+1-416-465-4655': set(['+1 416-465-4655']),
#  '+1-416-465-5757': set(['+1416 465-5757']),
#  '+1-416-465-7677': set(['(416) 465-7677']),
#  '+1-416-465-8085': set(['(416) 465-8085']),
#  '+1-416-466-0008': set(['416-466-0008']),
#  '+1-416-466-0261': set(['416-466-0261']),
#  '+1-416-466-1979': set(['+1-416-466-1979']),
#  '+1-416-466-2000': set(['+1 416 466 2000']),
#  '+1-416-466-2129': set(['416-466-2129']),
#  '+1-416-466-2131': set(['4164662131']),
#  '+1-416-466-2186': set(['416 466 2186 ext. 101']),
#  '+1-416-466-5371': set(['+1 416 466 5371']),
#  '+1-416-466-6568': set(['(416) 466-6568']),
#  '+1-416-466-8017': set(['+1 416 466 8017']),
#  '+1-416-466-8787': set(['416-466-8787']),
#  '+1-416-466-9693': set(['416.466.9693']),
#  '+1-416-466-9923': set(['4164669923']),
#  '+1-416-467-0177': set(['(416) 467-0177']),
#  '+1-416-467-2300': set(['+1 416 467 2300']),
#  '+1-416-467-5771': set(['416-467-5771']),
#  '+1-416-467-6060': set(['+1 416 467 6060']),
#  '+1-416-467-7557': set(['416-467-7557']),
#  '+1-416-467-8682': set(['(416) 467-8682']),
#  '+1-416-467-9111': set(['(416) 467-9111']),
#  '+1-905-916-8000': set(['+1 905 916-8000']),
#  '+1-905-916-9000': set(['905-916-9000']),
#  '+1-905-918-8888': set(['+1 905 918 8888']),
#  '+1-905-919-1374': set(['1 905 919 1374']),
#  '+1-905-919-3690': set(['+1 905 919-3690']),
#  '+1-905-919-9799': set(['905-919-9799']),
#  '+1-905-920-4956': set(['+1 905 920 4956']),
#  '+1-905-927-0100': set(['+1 905 927 0100']),
#  '+1-905-930-7381': set(['+1 905 930 7381']),
#  '+1-905-930-8400': set(['+1 905-930-8400']),
#  '+1-905-935-3535': set(['905.935.3535']),
#  '+1-905-936-1109': set(['+1-905-936-1109']),
#  '+1-905-936-2121': set(['+1-(905) 936-2121']),
#  '+1-905-936-2177': set(['+1 905 936-2177']),
#  '+1-905-936-3711': set(['+1 905 936-3711']),
#  '+1-905-938-8398': set(['9059388398']),
#  '+1-905-939-0575': set(['905-939-0575']),
#  '+1-905-939-0774': set(['+1-905-939-0774']),
#  '+1-905-939-1216': set(['905-939-1216']),
#  '+1-905-939-2012': set(['905-939-2012']),
#  '+1-905-939-2256': set(['(905) 939-2256']),
#  '+1-905-939-2323': set(['+1 905 939 2323']),
#  '+1-905-939-2394': set(['+1-905-939-2394']),
#  '+1-905-939-2582': set(['905-939-2582']),
#  '+1-905-939-3474': set(['905-939-3474']),
#  '+1-905-939-7751': set(['905-939-7751']),
#  '+1-905-939-7960': set(['+1-(905) 939-7960']),
#  '+1-905-939-8758': set(['905-939-8758']),
#  '+1-905-939-9454': set(['+1-(905) 939-9454']),
#  '+1-905-940-0235': set(['9059400235']),
#  '+1-905-940-1113': set(['+1(905)940-1113']),
#  '+1-905-940-1555': set(['9059401555']),
#  '+1-905-940-1900': set(['+1(905)940-1900']),
#  '+1-905-940-5554': set(['+1 905 940 5554']),
#  '+1-905-940-9400': set(['(905) 940-9400']),
#  '+1-905-943-9797': set(['9059439797']),
#  '+1-905-944-0004': set(['9059440004']),
#  '+1-905-944-0033': set(['+1-905-944-0033']),
#  '+1-905-944-8555': set(['9059448555']),
#  '+1-905-945-0300': set(['+1-905-945-0300']),
#  '+1-905-945-5437': set(['(905)945-5437']),
#  '+1-905-945-9628': set(['+1 905-945-9628']),
#  '+1-905-946-1995': set(['9059461995']),
#  '+1-905-947-0221': set(['9059470221']),
#  '+1-905-947-0527': set(['9059470527']),
#  '+1-905-947-9555': set(['9059479555']),
#  '+1-905-947-9777': set(['9059479777']),
#  '+1-905-947-9880': set(['(905)947-9880']),
#  '+1-905-948-0007': set(['9059480007']),
#  '+1-905-948-1618': set(['+1 (905) 948-1618']),
#  '+1-905-948-1785': set(['905-948-1785']),
#  '+1-905-948-9000': set(['(905)948-9000']),
#  '+1-905-949-0663': set(['9059490663']),
#  '+1-905-949-1592': set(['+1 905 949-1592']),
#  '+1-905-949-1632': set(['+1 905-949-1632']),
#  '+1-905-949-1700': set(['+1 905 949-1700']),
#  '+1-905-949-1793': set(['+1 905 949-1793']),
#  '+1-905-949-2220': set(['+1 905-949-2220']),
#  '+1-905-949-4447': set(['+1 905 949 4447']),
#  '+1-905-949-5533': set(['9059495533']),
#  '+1-905-949-6895': set(['9059496895']),
#  '+1-905-949-8000': set(['+1 905 949-8000']),
#  '+1-905-949-8878': set(['+1 905 949-8878']),
#  '+1-905-949-8899': set(['+1 905 949-8899']),
#  '+1-905-949-9766': set(['+1 905 949-9766']),
#  '+1-905-951-0942': set(['+1 905-951-0942']),
#  '+1-905-951-4100': set(['+1 905 951 4100']),
#  '+1-905-951-8325': set(['+1 905 951 8325']),
#  '+1-905-951-8333': set(['+1 905-951-8333']),
#  '+1-905-951-8935': set(['+1 905 951 8935']),
#  '+1-905-951-9555': set(['+1 905-951-9555']),
#  '+1-905-951-9999': set(['+1 905 951 9999']),
#  '+1-905-952-0782': set(['(905) 952-0782']),
#  '+1-905-953-1028': set(['+1 905 953 1028']),
#  '+1-905-953-1609': set(['905-953-1609']),
#  '+1-905-953-2818': set(['+1-905-953-2818']),
#  '+1-905-953-5110': set(['+1 905 953 5110']),
#  '+1-905-954-0090': set(['905-954-0090']),
#  '+1-905-954-0202': set(['905-954-0202']),
#  '+1-905-954-0289': set(['+1 905 954 0289']),
#  '+1-905-954-0476': set(['(905) 954-0476']),
#  '+1-905-954-0908': set(['(905) 954-0908']),
#  '+1-905-954-1327': set(['905-954-1327']),
#  '+1-905-956-1533': set(['+1 905 956-1533']),
#  '+1-905-956-2007': set(['+1 905 956-2007']),
#  '+1-905-956-2233': set(['+1 905 956-2233']),
#  '+1-905-956-6111': set(['+1 905 956-6111']),
#  '+1-905-956-8600': set(['+! 905 956-8600']),
#  '+1-905-963-1365': set(['+1 (905) 963-1365']),
#  '+1-905-966-1890': set(['+1.905.966.1890']),
#  '+1-905-967-0888': set(['+1 905 967 0888']),
#  '+1-905-967-1111': set(['905-967-1111']),
#  '+1-905-967-1237': set(['905-967-1237']),
#  '+1-905-967-8866': set(['+1 905 967 8866']),
#  '+1-905-970-2080': set(['+1-905-970-2080']),
#  '+1-905-970-8045': set(['+1 905 970 8045']),
#  '+1-905-970-8100': set(['+1 905 970-8100']),
#  '+1-905-970-9655': set(['905-970-9655']),
#  '+1-905-970-9711': set(['+1 905 970 9711']),
#  '+1-905-970-9886': set(['+1 905 970 9886']),
#  '+1-905-970-9988': set(['905-970-9988']),
#  '+1-905-973-4000': set(['+1 905 973-4000']),
#  '+1-905-973-4702': set(['905 973 4702']),
#  '+1-905-973-4709': set(['+1 905 973-4709']),
#  '+1-905-985-0009': set(['+1-905-985-0009']),
#  '+1-905-985-0069': set(['+1-905-985-0069']),
#  '+1-905-985-4573': set(['+1-905-985-4573']),
#  '+1-905-985-7849': set(['+1-905-985-7849']),
#  '+1-905-985-8177': set(['+1-905-985-8177']),
#  '+1-905-985-9292': set(['905-985-9292']),
#  '+1-905-985-9570': set(['+1-905-985-9570']),
#  '+1-905-985-9924': set(['+1 905-985-9924']),
#  '+1-905-985-9932': set(['9059859932']),
#  '+1-905-986-0017': set(['+1-905-986-0017']),
#  '+1-905-986-5620': set(['+1-905-986-5620']),
#  '+1-905-989-67733': set(['90598967733']),
#  '+1-905-990-0094': set(['1 905 990 0094']),
#  '+1-905-990-0834': set(['905-990-0834']),
#  '+1-905-990-0862': set(['905-990-0862']),
#  '+1-905-990-1174': set(['9059901174']),
#  '+1-905-990-1345': set(['+1 905 990-1345']),
#  '+1-905-990-2084': set(['1 905 990 2084']),
#  '+1-905-990-2427': set(['+1 905 990-2427']),
#  '+1-905-990-2868': set(['9059902868']),
#  '+1-905-990-3473': set(['+1 905 990-3473']),
#  '+1-905-990-3689': set(['+1 905-990-3689']),
#  '+1-905-990-4242': set(['+1 905-990-4242']),
#  '+1-905-990-4300': set(['+1 905 990-4300']),
#  '+1-905-990-4455': set(['+1 905 990-4455']),
#  '+1-905-990-5433': set(['+1 905-990-5433']),
#  '+1-905-990-5454': set(['905-990-5454']),
#  '+1-905-990-5522': set(['+1 905 990-5522']),
#  '+1-905-990-6100': set(['+1 905 990-6100']),
#  '+1-905-990-7222': set(['1 905 990 7222']),
#  '+1-905-990-7700': set(['905-990-7700']),
#  '+1-905-990-7890': set(['+1 905-990-7890']),
#  '+1-905-990-8387': set(['1 905 990 8387']),
#  '+1-905-990-8400': set(['+1 905-990-8400']),
#  '+1-905-990-8887': set(['+1-905-990-8887']),
#  '+1-905-990-9088': set(['+1 905 990-9088']),
#  '+1-905-990-9199': set(['+1 905 990-9199']),
#  '+1-905-990-9220': set(['+1 905-990-9220']),
#  '+1-905-992-6862': set(['+1 905 992-6862']),
#  '+1-905-995-7400': set(['+1 905 995 7400']),
#  '+1-905-997-3320': set(['+1 905 997-3320']),
#  '+1-905-997-4311': set(['+1 905 997 4311']),
#  '+1-905-997-4434': set(['+1 905 997-4434']),
#  '+1-905-997-4700': set(['+1 905 997-4700']),
#  '+1-905-997-5510': set(['905-997-5510']),
#  '+1-905-997-6453': set(['+1 905 997-6453']),
#  '+1-905-997-7774': set(['+1 905 997-7774']),
#  '+1-905-997-8088': set(['905-997-8088']),
#  '+1-905-997-8100': set(['+1 905 997-8100']),
#  '+1-905-997-8119': set(['+1 905 997-8119']),
#  '+1-905-997-8271': set(['905-997-8271']),
#  '+1-905-997-8378': set(['+1 905 997 8378']),
#  '+1-905-997-8555': set(['+1 905 997-8555']),
#  '+1-905-997-9080': set(['905-997-9080']),
#  '+1-906-458-1212': set(['906-458-1212']),
#  'unknown': set(['(416) 536-SODA',
#                  '+1 416 23-0009',
#                  '+1 416-201-960',
#                  '+1 416-535-936',
#                  '+1 416-539-259',
#                  '+1 821-8999',
#                  '+1 905 -90-4110',
#                  '+1 905 89-0820',
#                  '+1 905-461-',
#                  '+1 905-56-8999',
#                  '+1 95 542-7900',
#                  '+1(905)305-108',
#                  '+1-',
#                  '+41 66 65 7580',
#                  '1 905 891 001',
#                  '1 905 891 326',
#                  '1-800-AMNESTY',
#                  '1-905-477-ARMS',
#                  '12714100',
#                  '1800 royal 11',
#                  '19110911',
#                  '251-3007',
#                  '310-0001',
#                  '310-1010',
#                  '310-7171',
#                  '3104466',
#                  '338-5181',
#                  '416-486-foot',
#                  '416-962-ship',
#                  '416250LUXE',
#                  '416393PARK',
#                  '426-6434',
#                  '439-0000',
#                  '533-8110',
#                  '647 352 paws',
#                  '647-350UGLO',
#                  '647-996-CPAP',
#                  '905-632-1TAN',
#                  '905-681-1SPA',
#                  '905-864-333',
#                  '905-990-gums',
#                  '967-1111',
#                  '977-4444',
#                  u'Friday 9AM\u20139PM Saturday 9AM\u20135PM Sunday Closed Monday 9AM\u20139PM Tuesday 9AM\u20139PM Wednesday 9AM\u20139PM Thursday 9AM\u20139PM',
#                  'v'])}

# %% [markdown]
# Seeing abnormal or not regular format phone numbers as following
#
#  'unknown': set(['(416) 536-SODA',
#                  '+1 905 -90-4110',
#                  '1 905 891 326',
#                  '439-0000'])}

# %%
7. Find out how many unique users have contributed to the map in this particular area.

# %%
#The function process_map should return a set of unique user IDs ("uid")

import xml.etree.cElementTree as ET
import pprint
import re

def get_user(element):
    if element.get('uid'):
        return element.get('uid')
    
def process_map(filename):
    users = set()
    for _, element in ET.iterparse(filename):
        users.add(get_user(element))
        users.discard(None)
    return users

def test():

    users = process_map('toronto_canada3.osm')
    pprint.pprint(users)


if __name__ == "__main__":
    test()
# Out:
# set(['1',
#      '100337',
#      '100419',
#      '1007022',
#      '1007528',
#      '100917',
#      '1009527',
#      '101184',
#      '1012362',
#      '1015527',
#      '1015528',
#      '1015531',
#      '1015532',
#      '1015536',
#      '1015542',
#      '102064',
#      '10225',
#      '102410',
#      '102723',
#      '103253',
#      '1035032',
#      '10353',
#      '103530',
#      '1035507',
#      '103574',
#      '103816',
#      '1044834',
#      '104519',
#      '1051550',
#      '105255',
#      '105603',
#      '105839',
#      '1058666',
#      '1060930',
#      '106293',
#      '1063003',
#      '1066031',
#      '106858',
#      '106874',
#      '106914',
#      '1069176',
#      '10716',
#      '1074988',
#      '10786',
#      '10788',
#      '107884',
#      '1080971',
#      '1083420',
#      '108634',
#      '1087647',
#      '109002',
#      '10927',
#      '1093914',
#      '109925',
#      '110046',
#      '110253',
#      '110263',
#      '1103322',
#      '1103744',
#      '1106095',
#      '1108251',
#      '110915',
#      '1110934',
#      '1114651',
#      '111504',
#      '1121958',
#      '1126371',
#      '113450',
#      '1134642',
#      '113624',
#      '113813',
#      '113934',
#      '1140903',
#      '114161',
#      '114220',
#      '1143903',
#      '115102',
#      '115159',
#      '1154235',
#      '115814',
#      '116309',
#      '1165188',
#      '117027',
#      '1171541',
#      '117548',
#      '118021',
#      '11810',
#      '118168',
#      '1181708',
#      '118262',
#      '1186499',
#      '118722',
#      '118856',
#      '1189040',
#      '119304',
#      '1193517',
#      '1197379',
#      '1198074',
#      '119881',
#      '1199488',
#      '1199616',
#      '120146',
#      '120468',
#      '1208453',
#      '1208668',
#      '1208684',
#      '1208840',
#      '120989',
#      '1209932',
#      '1211588',
#      '1211598',
#      '1211655',
#      '1211661',
#      '1211692',
#      '1211739',
#      '1212573',
#      '1214881',
#      '1216381',
#      '1217542',
#      '1218455',
#      '1218457',
#      '1219020',
#      '122048',
#      '1224467',
#      '1224650',
#      '122516',
#      '1225187',
#      '1953481',
#      '1956002',
#      '195663',
#      '195666',
#      '195677',
#      '1959334',
#      '1959672',
#      '1960024',
#      '1961440',
#      '1962477',
#      '1962623',
#      '1962659',
#      '1962782',
#      '1962905',
#      '1962934',
#      '1963599',
#      '1963724',
#      '1963914',
#      '1963934',
#      '1963952',
#      '1964104',
#      '1964162',
#      '1964238',
#      '1965726',
#      '1965930',
#      '1970440',
#      '197118',
#      '1973835',
#      '1973906',
#      '1974689',
#      '1976468',
#      '1976822',
#      '197722',
#      '1979426',
#      '1980351',
#      '1986674',
#      '1988324',
#      '1989383',
#      '1989629',
#      '199073',
#      '199106',
#      '1995341',
#      '1996396',
#      '2000641',
#      '2001661',
#      '2001989',
#      '2003355',
#      '2005182',
#      '200840',
#      '2009591',
#      '2012449',
#      '201359',
#      '2014256',
#      '2015224',
#      '2016441',
#      '2019927',
#      '2021243',
#      '202256',
#      '2026613',
#      '2027890',
#      '2032009',
#      '2034065',
#      '203688',
#      '2039569',
#      '204153',
#      '2042447',
#      '2045205',
#      '2049383',
#      '20496',
#      '2050137',
#      '2052519',
#      '205520',
#      '205523',
#      '2055274',
#      '205587',
#      '2056606',
#      '2057798',
#      '205828',
#      '2062459',
#      '2063093',
#      '2063782',
#      '2066842',
#      '2070701',
#      '2070839',
#      '20714',
#      '2072022',
#      '2072778',
#      '207745',
#      '2081424',
#      '2082200',
#      '2082547',
#      '2084825',
#      '20855',
#      '2086569',
#      '2087416',
#      '2088126',
#      '2088224',
#      '2088311',
#      '2093988',
#      '2097109',
#      '2098826',
#      '2103963',
#      '2108375',
#      '2111466',
#      '2114319',
#      '2115749',
#      '2122262',
#      '2122722',
#      '2126290',
#      '2128934',
#      '2136895',
#      '2137416',
#      '213831',
#      '214103',
#      '2146265',
#      '2146423',
#      '2146930',
#      '2146944',
#      '214969',
#      '215255',
#      '2152724',
#      '2153606',
#      '2157702',
#      '2161419',
#      '216373',
#      '2168589',
#      '217070',
#      '2176607',
#      '2182224',
#      '2182734',
#      '218367',
#      '2185658',
#      '2199723',
#      '220320',
#      '2209894',
#      '2210086',
#      '2215332',
#      '2219338',
#      '2219710',
#      '2219985',
#      '2220291',
#      '222197',
#      '2222125',
#      '22224',
#      '2225064',
#      '2226712',
#      '2229469',
#      '223056',
#      '2231',
#      '2232640',
#      '22347',
#      '2237931',
#      '2240406',
#      '2242703',
#      '224440',
#      '2249711',
#      '2250878',
#      '2250906',
#      '2250942',
#      '2252606',
#      '2252732',
#      '2252958',
#      '2253772',
#      '2254691',
#      '2261773',
#      '2262996',
#      '2263879',
#      '2264595',
#      '2265216',
#      '2267193',
#      '2268215',
#      '22684',
#      '2268702',
#      '2269884',
#      '2277882',
#      '2280235',
#      '2281286',
#      '2285064',
#      '2288344',
#      '2290988',
#      '2292235',
#      '22925',
#      '2293960',
#      '2296427',
#      '2298660',
#      '2301023',
#      '23017',
#      '2302963',
#      '2306749',
#      '2309448',
#      '23105',
#      '2311468',
#      '231187',
#      '2314002',
#      '2315825',
#      '231616',
#      '2316730',
#      '2318881',
#      '2321092',
#      '232126',
#      '232133',
#      '2334279',
#      '23351',
#      '2336893',
#      '23426',
#      '2344820',
#      '2349071',
#      '234955',
#      '235069',
#      '235294',
#      '2362154',
#      '2362678',
#      '2363005',
#      '236361',
#      '2363631',
#      '236412',
#      '23663',
#      '2368213',
#      '2371310',
#      '237556',
#      '2376',
#      '2376134',
#      '2377377',
#      '238145',
#      '2381715',
#      '238584',
#      '2387099',
#      '238859',
#      '2389639',
#      '239035',
#      '2392578',
#      '239998',
#      '240041',
#      '240210',
#      '2405890',
#      '2406578',
#      '2410326',
#      '24126',
#      '2416016',
#      '2416679',
#      '2417',
#      '2419153',
#      '2420800',
#      '2422265',
#      '2422275',
#      '2422852',
#      '2428141',
#      '2432438',
#      '243263',
#      '2435130',
#      '2438428',
#      '2440160',
#      '2441592',
#      '2442357',
#      '24440',
#      '2445224',
#      '2446383',
#      '2455167',
#      '24555',
#      '2455828',
#      '2456530',
#      '2457640',
#      '245844',
#      '2459580',
#      '2460845',
#      '2462842',
#      '246643',
#      '2471547',
#      '247290',
#      '2474226',
#      '247879',
#      '2482761',
#      '248482',
#      '248743',
#      '2489224',
#      '2492308',
#      '249383',
#      '249523',
#      '249634',
#      '249843',
#      '2503544',
#      '250710',
#      '2508151',
#      '2511706',
#      '2511896',
#      '2512300',
#      '251543',
#      '251720',
#      '2517801',
#      '2524301',
#      '252440',
#      '252811',
#      '2529424',
#      '253074',
#      '253748',
#      '254028',
#      '2540987',
#      '2544139',
#      '2545951',
#      '25504',
#      '2550748',
#      '2553854',
#      '2553996',
#      '2554698',
#      '2555463',
#      '2555923',
#      '2558444',
#      '2564243',
#      '2566007',
#      '2567634',
#      '256856',
#      '2571997',
#      '2575201',
#      '2575268',
#      '2575285',
#      '2575309',
#      '2575311',
#      '2575312',
#      '2575323',
#      '2575783',
#      '258023',
#      '2585',
#      '2590084',
#      '2592971',
#      '2592997',
#      '2593598',
#      '2593698',
#      '2593722',
#      '2593747',
#      '2593816',
#      '2593856',
#      '2596304',
#      '2599516',
#      '2603821',
#      '2606223',
#      '2608568',
#      '2610040',
#      '2610982',
#      '2611068',
#      '2611828',
#      '2612000',
#      '2612335',
#      '262151',
#      '2622386',
#      '2625412',
#      '2628704',
#      '26299',
#      '2631935',
#      '26348',
#      '2644101',
#      '2644810',
#      '2650053',
#      '2655992',
#      '2656956',
#      '26599',
#      '266992',
#      '267080',
#      '26741',
#      '2675',
#      '2677496',
#      '2677841',
#      '2680',
#      '26818',
#      '2682373',
#      '268371',
#      '2696454',
#      '2698332',
#      '269986',
#      '2705',
#      '2706739',
#      '2715440',
#      '2716442',
#      '2718110',
#      '2718968',
#      '2720055',
#      '27287',
#      '2735849',
#      '2739599',
#      '273986',
#      '2740857',
#      '274240',
#      '2743547',
#      '2744797',
#      '2748195',
#      '274857',
#      '2750389',
#      '2751980',
#      '275403',
#      '2756016',
#      '2761292',
#      '2762183',
#      '2762928',
#      '2764393',
#      '2766511',
#      '2767519',
#      '276771',
#      '277100',
#      '2772299',
#      '2773196',
#      '2777051',
#      '2781190',
#      '2781466',
#      '2781619',
#      '278964',
#      '2800396',
#      '2804565',
#      '2804920',
#      '2812604',
#      '281267',
#      '2813997',
#      '28145',
#      '28150',
#      '2815098',
#      '2815109',
#      '2818856',
#      '282329',
#      '2823295',
#      '28236',
#      '2834933',
#      '2835928',
#      '28378',
#      '2839290',
#      '284247',
#      '2844717',
#      '2845963',
#      '2846070',
#      '2847988',
#      '284878',
#      '2849202',
#      '285439',
#      '28559',
#      '28609',
#      '2867517',
#      '28692',
#      '286993',
#      '2871237',
#      '2875778',
#      '2877466',
#      '28775',
#      '28783',
#      '287920',
#      '28794',
#      '2885410',
#      '2887082',
#      '28895',
#      '2889570',
#      '2889573',
#      '2892414',
#      '290271',
#      '2905914',
#      '2906558',
#      '2906790',
#      '290680',
#      '2906896',
#      '29084',
#      '2910314',
#      '291298',
#      '2914618',
#      '291965',
#      '292007',
#      '2920397',
#      '2925062',
#      '292575',
#      '2926215',
#      '292665',
#      '2929338',
#      '2933462',
#      '293774',
#      '29403',
#      '2944689',
#      '2946504',
#      '2953422',
#      '2954807',
#      '2957953',
#      '2959379',
#      '296145',
#      '2962531',
#      '2962751',
#      '296379',
#      '296562',
#      '296708',
#      '296821',
#      '2970000',
#      '297004',
#      '297007',
#      '297050',
#      '297295',
#      '297552',
#      '2985232',
#      '2987110',
#      '2987426',
#      '2987662',
#      '29891',
#      '30035',
#      '300459',
#      '3006999',
#      '3013682',
#      '3014357',
#      '301440',
#      '301502',
#      '3023612',
#      '3028208',
#      '302871',
#      '3029661',
#      '3031413',
#      '3031741',
#      '30383',
#      '3045748',
#      '3048291',
#      '30521',
#      '3057995',
#      '305985',
#      '3065461',
#      '3066062',
#      '306955',
#      '307499',
#      '307520',
#      '308063',
#      '3082450',
#      '3082520',
#      '3084712',
#      '3089460',
#      '3090661',
#      '309351',
#      '3094746',
#      '3095',
#      '3098149',
#      '3099745',
#      '3100811',
#      '3102978',
#      '3105226',
#      '310589',
#      '31075',
#      '311102',
#      '31118',
#      '3118451',
#      '3118473',
#      '3121532',
#      '31231',
#      '3123161',
#      '3125856',
#      '3127',
#      '31385',
#      '3138860',
#      '3143354',
#      '31437',
#      '314870',
#      '3151684',
#      '3151775',
#      '3151933',
#      '3158205',
#      '316287',
#      '3164012',
#      '316510',
#      '31665',
#      '316694',
#      '316947',
#      '31699',
#      '3178375',
#      '3181481',
#      '318171',
#      '3183396',
#      '3184960',
#      '319202',
#      '319464',
#      '319769',
#      '3201434',
#      '3207986',
#      '3210266',
#      '3210530',
#      '3220996',
#      '3224972',
#      '322785',
#      '3229676',
#      '323252',
#      '3234',
#      '3235691',
#      '323757',
#      '3240094',
#      '3240352',
#      '324385',
#      '324428',
#      '3244701',
#      '3246',
#      '3246031',
#      '3249812',
#      '3249988',
#      '3250451',
#      '3252237',
#      '325294',
#      '3253745',
#      '3254724',
#      '3257194',
#      '3257893',
#      '325973',
#      '3262666',
#      '3263010',
#      '3263523',
#      '326387',
#      '3264157',
#      '32700',
#      '3272191',
#      '3272286',
#      '3273339',
#      '3275802',
#      '3277198',
#      '3277801',
#      '3278361',
#      '327927',
#      '3281342',
#      '3285415',
#      '3289825',
#      '3292570',
#      '329453',
#      '3294534',
#      '32952',
#      '3296371',
#      '3296488',
#      '329877',
#      '3299014',
#      '329962',
#      '3301159',
#      '3301453',
#      '3302189',
#      '3303698',
#      '330773',
#      '3307866',
#      '3309033',
#      '3309071',
#      '3316076',
#      '331840',
#      '33215',
#      '3322143',
#      '332742',
#      '33321',
#      '33331',
#      '3345872',
#      '334818',
#      '3348337',
#      '334954',
#      '3354568',
#      '3355439',
#      '3355449',
#      '3356403',
#      '336049',
#      '3362013',
#      '3363664',
#      '3363667',
#      '3363668',
#      '3363669',
#      '3363684',
#      '336460',
#      '3365078',
#      '3373171',
#      '3389273',
#      '3392181',
#      '339581',
#      '339917',
#      '3404894',
#      '3406980',
#      '34114',
#      '3411456',
#      '3412095',
#      '3414246',
#      '341519',
#      '3418895',
#      '3424307',
#      '3426591',
#      '3428022',
#      '3428922',
#      '3431934',
#      '3432400',
#      '3445429',
#      '3447930',
#      '345562',
#      '3455990',
#      '345833',
#      '3460649',
#      '3467171',
#      '346758',
#      '3471670',
#      '3477353',
#      '3478684',
#      '3479270',
#      '348565',
#      '3486013',
#      '3491496',
#      '34953',
#      '3497841',
#      '349919',
#      '350549',
#      '3516',
#      '3516872',
#      '3522089',
#      '352368',
#      '35243',
#      '3524587',
#      '3524812',
#      '3526564',
#      '3528573',
#      '3529129',
#      '3537901',
#      '3545726',
#      '3551873',
#      '3551880',
#      '355210',
#      '355242',
#      '355617',
#      '3561353',
#      '356473',
#      '356740',
#      '3570545',
#      '3570546',
#      '3572302',
#      '3577696',
#      '3582',
#      '3592311',
#      '3594119',
#      '3597834',
#      '359990',
#      '360392',
#      '360480',
#      '3605995',
#      '360822',
#      '36121',
#      '3615102',
#      '3615106',
#      '3615110',
#      '3615112',
#      '3615114',
#      '3615127',
#      '3615141',
#      '3615144',
#      '3615145',
#      '3615146',
#      '3615169',
#      '3615171',
#      '3615178',
#      '3615191',
#      '3615231',
#      '3618056',
#      '3618071',
#      '3618084',
#      '3618136',
#      '3618198',
#      '362107',
#      '3621290',
#      '3621571',
#      '36223',
#      '3630939',
#      '3632491',
#      '3633512',
#      '3636245',
#      '363803',
#      '3638627',
#      '3642265',
#      '3642441',
#      '3642793',
#      '3642847',
#      '3642909',
#      '3642945',
#      '3643219',
#      '3643482',
#      '3645304',
#      '364790',
#      '364916',
#      '3650730',
#      '3651808',
#      '3656118',
#      '365897',
#      '3659083',
#      '3663623',
#      '366834',
#      '36694',
#      '3673398',
#      '36737',
#      '3675101',
#      '3675236',
#      '3676570',
#      '3679137',
#      '368614',
#      '368874',
#      '3695876',
#      '3696414',
#      '3696841',
#      '37074',
#      '37137',
#      '3714149',
#      '3720404',
#      '3720929',
#      '3724915',
#      '3741753',
#      '3747854',
#      '37548',
#      '3755964',
#      '3758399',
#      '3760084',
#      '376330',
#      '3769434',
#      '3770899',
#      '692602',
#      '692614',
#      '693098',
#      '693104',
#      '693212',
#      '693442',
#      '694123',
#      '694140',
#      '694726',
#      '69607',
#      '696201',
#      '6975',
#      '69763',
#      '69853',
#      '701297',
#      '701345',
#      '70235',
#      '70260',
#      '703517',
#      '705850',
#      '706170',
#      '706634',
#      '70672',
#      '70696',
#      '70742',
#      '710590',
#      '711251',
#      '711509',
#      '71241',
#      '71261',
#      '714383',
#      '715087',
#      '71555',
#      '71557',
#      '716675',
#      '7168',
#      '72056',
#      '7221',
#      '722137',
#      '72235',
#      '729',
#      '733850',
#      '73405',
#      '734714',
#      '735',
#      '736',
#      '737775',
#      '74448',
#      '74508',
#      '7464',
#      '74937',
#      '751546',
#      '756894',
#      '757235',
#      '76002',
#      '760215',
#      '76077',
#      '762180',
#      '7630',
#      '76343',
#      '76689',
#      '768145',
#      '76908',
#      '7702',
#      '77114',
#      '772688',
#      '77804',
#      '77995',
#      '78656',
#      '79203',
#      '79336',
#      '80150',
#      '802468',
#      '80285',
#      '8047',
#      '80605',
#      '809546',
#      '81285',
#      '81616',
#      '822901',
#      '82389',
#      '82454',
#      '82553',
#      '82848',
#      '83120',
#      '83152',
#      '8339',
#      '834127',
#      '837425',
#      '83854',
#      '83907',
#      '840019',
#      '842286',
#      '842300',
#      '842611',
#      '8430',
#      '843384',
#      '84464',
#      '845605',
#      '84681',
#      '848873',
#      '8498',
#      '850941',
#      '85218',
#      '853144',
#      '858666',
#      '85995',
#      '86279',
#      '863314',
#      '86504',
#      '86618',
#      '86845',
#      '8703',
#      '870861',
#      '873424',
#      '876637',
#      '87877',
#      '88164',
#      '88337',
#      '88726',
#      '8909',
#      '89128',
#      '893541',
#      '898696',
#      '90400',
#      '904907',
#      '904961',
#      '90780',
#      '90787',
#      '908911',
#      '910207',
#      '91139',
#      '912016',
#      '91313',
#      '91490',
#      '91499',
#      '915076',
#      '91657',
#      '91790',
#      '919769',
#      '92076',
#      '92209',
#      '92274',
#      '92286',
#      '925947',
#      '92893',
#      '932674',
#      '933224',
#      '938810',
#      '93983',
#      '94055',
#      '94062',
#      '94442',
#      '94558',
#      '94578',
#      '950182',
#      '951370',
#      '951872',
#      '953558',
#      '955852',
#      '96069',
#      '96698',
#      '96702',
#      '967832',
#      '972981',
#      '97404',
#      '977021',
#      '977708',
#      '98914',
#      '99022',
#      '99057',
#      '99083',
#      '99276',
#      '99762'])

# %% [markdown]
# ### 4. Prepair for Database SQL
#
# After auditing is complete the next step is to prepare the data to be inserted into a SQL database.
#    To do so I will parse the elements in the OSM XML file, transforming them from document format to
#    tabular format.
#
#    Making it possible to write to .csv files.  These csv files can then easily be imported to a SQL database as tables.
#
# The process for this transformation is as follows:
# - Use iterparse to iteratively step through each top level element in the XML
# - Shape each element into several data structures using a custom function
# - Utilize a schema and validation library to ensure the transformed data is in the correct format
# - Write each data structure to the appropriate .csv files
#
# #### From the Case study
#
# I've already provided the code needed to load the data, perform iterative parsing and write the
# output to csv files. My task is to complete the shape_element function that will transform each
# element into the correct format. To make this process easier we've already defined a schema (schema.py)
# for the .csv files and the eventual tables. Using the cerberus library we can validate the output
# against this schema to ensure it is correct.
#
# Shape Element Function
# The function should take as input an iterparse Element object and return a dictionary.
#
# If the element top level tag is "node":
# The dictionary returned should have the format {"node": .., "node_tags": ...}
#
# The "node" field should hold a dictionary of the following top level node attributes:
# - id
# - user
# - uid
# - version
# - lat
# - lon
# - timestamp
# - changeset
# All other attributes can be ignored
#
# The "node_tags" field should hold a list of dictionaries, one per secondary tag. Secondary tags are
# child tags of node which have the tag name/type: "tag". Each dictionary should have the following
# fields from the secondary tag attributes:
# - id: the top level node id attribute value
# - key: the full tag "k" attribute value if no colon is present or the characters after the colon if one is.
# - value: the tag "v" attribute value
# - type: either the characters before the colon in the tag "k" value or "regular" if a colon is not present.
#
# Additionally,
#
# - if the tag "k" value contains problematic characters, the tag should be ignored
# - if the tag "k" value contains a ":" the characters before the ":" should be set as the tag type
#   and characters after the ":" should be set as the tag key
# - if there are additional ":" in the "k" value they and they should be ignored and kept as part of
#   the tag key. For example:
#
#   <tag k="addr:street:name" v="Lincoln"/>
#   should be turned into
#   {'id': 12345, 'key': 'street:name', 'value': 'Lincoln', 'type': 'addr'}
#
# - If a node has no secondary tags then the "node_tags" field should just contain an empty list.

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

import csv
import codecs
import pprint
import re
import xml.etree.cElementTree as ET
import cerberus
import sys
import schema

OSM_PATH = "toronto_canada3.osm"

NODES_PATH = "nodes.csv"
NODE_TAGS_PATH = "nodes_tags.csv"
WAYS_PATH = "ways.csv"
WAY_NODES_PATH = "ways_nodes.csv"
WAY_TAGS_PATH = "ways_tags.csv"

LOWER_COLON = re.compile(r'^([a-z]|_)+:([a-z]|_)+')
PROBLEMCHARS = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

SCHEMA = schema.schema

# Make sure the fields order in the csvs matches the column order in the sql table schema
NODE_FIELDS = ['id', 'lat', 'lon', 'user', 'uid', 'version', 'changeset', 'timestamp']
NODE_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_FIELDS = ['id', 'user', 'uid', 'version', 'changeset', 'timestamp']
WAY_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_NODES_FIELDS = ['id', 'node_id', 'position']


def shape_element(element, node_attr_fields=NODE_FIELDS, way_attr_fields=WAY_FIELDS,
                  problem_chars=PROBLEMCHARS, default_tag_type='regular'):
    """Clean and shape node or way XML element to Python dict"""

    node_attribs = {}
    way_attribs = {}
    way_nodes = []
    tags = []  

    if element.tag == 'node':
        for attrib in element.attrib:
            if attrib in NODE_FIELDS:
                node_attribs[attrib] = element.attrib[attrib]
        
        for child in element:
            node_tag = {}
            if LOWER_COLON.match(child.attrib['k']):
                node_tag['type'] = child.attrib['k'].split(':',1)[0]
                node_tag['key'] = child.attrib['k'].split(':',1)[1]
                node_tag['id'] = element.attrib['id']
                node_tag['value'] = child.attrib['v']
                tags.append(node_tag)
            elif PROBLEMCHARS.match(child.attrib['k']):
                continue
            else:
                node_tag['type'] = 'regular'
                node_tag['key'] = child.attrib['k']
                node_tag['id'] = element.attrib['id']
                node_tag['value'] = child.attrib['v']
                tags.append(node_tag)
        
        return {'node': node_attribs, 'node_tags': tags}
        
    elif element.tag == 'way':
        for attrib in element.attrib:
            if attrib in WAY_FIELDS:
                way_attribs[attrib] = element.attrib[attrib]
        
        position = 0
        for child in element:
            way_tag = {}
            way_node = {}
            
            if child.tag == 'tag':
                if LOWER_COLON.match(child.attrib['k']):
                    way_tag['type'] = child.attrib['k'].split(':',1)[0]
                    way_tag['key'] = child.attrib['k'].split(':',1)[1]
                    way_tag['id'] = element.attrib['id']
                    way_tag['value'] = child.attrib['v']
                    tags.append(way_tag)
                elif PROBLEMCHARS.match(child.attrib['k']):
                    continue
                else:
                    way_tag['type'] = 'regular'
                    way_tag['key'] = child.attrib['k']
                    way_tag['id'] = element.attrib['id']
                    way_tag['value'] = child.attrib['v']
                    tags.append(way_tag)
                    
            elif child.tag == 'nd':
                way_node['id'] = element.attrib['id']
                way_node['node_id'] = child.attrib['ref']
                way_node['position'] = position
                position += 1
                way_nodes.append(way_node)
        
        return {'way': way_attribs, 'way_nodes': way_nodes, 'way_tags': tags}

# ================================================== #
#               Helper Functions                     #
# ================================================== #
def get_element(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag"""

    context = ET.iterparse(osm_file, events=('start', 'end'))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()


def validate_element(element, validator, schema=SCHEMA):
    """Raise ValidationError if element does not match schema"""
    if validator.validate(element, schema) is not True:
        field, errors = next(validator.errors.iteritems())
        message_string = "\nElement of type '{0}' has the following errors:\n{1}"
        error_string = pprint.pformat(errors)
        
        raise Exception(message_string.format(field, error_string))


class UnicodeDictWriter(csv.DictWriter, object):
    """Extend csv.DictWriter to handle Unicode input"""

    def writerow(self, row):
        super(UnicodeDictWriter, self).writerow({
            k: (v.encode('utf-8') if isinstance(v, unicode) else v) for k, v in row.iteritems()
        })

    def writerows(self, rows):
        for row in rows:
            self.writerow(row)


# ================================================== #
#               Main Function                        #
# ================================================== #
def process_map(file_in, validate):
    """Iteratively process each XML element and write to csv(s)"""

    with codecs.open(NODES_PATH, 'w') as nodes_file, \
         codecs.open(NODE_TAGS_PATH, 'w') as nodes_tags_file, \
         codecs.open(WAYS_PATH, 'w') as ways_file, \
         codecs.open(WAY_NODES_PATH, 'w') as way_nodes_file, \
         codecs.open(WAY_TAGS_PATH, 'w') as way_tags_file:

        nodes_writer = UnicodeDictWriter(nodes_file, NODE_FIELDS)
        node_tags_writer = UnicodeDictWriter(nodes_tags_file, NODE_TAGS_FIELDS)
        ways_writer = UnicodeDictWriter(ways_file, WAY_FIELDS)
        way_nodes_writer = UnicodeDictWriter(way_nodes_file, WAY_NODES_FIELDS)
        way_tags_writer = UnicodeDictWriter(way_tags_file, WAY_TAGS_FIELDS)

        nodes_writer.writeheader()
        node_tags_writer.writeheader()
        ways_writer.writeheader()
        way_nodes_writer.writeheader()
        way_tags_writer.writeheader()

        validator = cerberus.Validator()

        for element in get_element(file_in, tags=('node', 'way')):
            el = shape_element(element)
            if el:
                if validate is True:
                    validate_element(el, validator)

                if element.tag == 'node':
                    nodes_writer.writerow(el['node'])
                    node_tags_writer.writerows(el['node_tags'])
                elif element.tag == 'way':
                    ways_writer.writerow(el['way'])
                    way_nodes_writer.writerows(el['way_nodes'])
                    way_tags_writer.writerows(el['way_tags'])


if __name__ == '__main__':
    # Note: Validation is ~ 10X slower. For the project consider using a small
    # sample of the map when validating.
    #process_map(OSM_PATH, validate=False)
    process_map(OSM_PATH, validate=True)
